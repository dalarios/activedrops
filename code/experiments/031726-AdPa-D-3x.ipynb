# %%
## Import relevant libraries
import sys
import glob

sys.path.append('../../py_files/')
import quadrop2 as qd

qd.set_plotting_style()

# %% [markdown]
# ### Data pre-procesing

# %%
# # Example usage
# base_dir = "../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-AcSu-3x/"
# qd.consolidate_images(base_dir)

# %%
# Example usage
data_path = "../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/"

calibration_curve_paths = sorted(glob.glob("../../../../Thomson Lab Dropbox/David Larios/activedrops/calibration-50ms/***ugml.tif"))

conditions_dict = {
    "AdPa-1": "Pos0",
    "AdPa-2": "Pos1",
    "AdPa-3": "Pos2",
    "D-1": "Pos3",
    "D-2": "Pos4",
    "D-3": "Pos5",
}

# Organize PosX folders into condition folders
qd.organize_conditions(data_path, conditions_dict)

# Now run the existing functions to reorganize the tiffs and rename the folders
conditions, subconditions = qd.prepare_conditions(data_path)
time_interval_list = [20] * len(conditions)  # time intervals in seconds between frames for each condition

subconditions = ['Rep1']
print("Conditions:", conditions)
print("Subconditions:", subconditions)
# Out:
# Conditions: ['AdPa-1', 'AdPa-2', 'AdPa-3', 'D-1', 'D-2', 'D-3']
# Subconditions: ['Rep1']

# %%
qd.reorgTiffsToOriginal(data_path, conditions, subconditions)
# Out:
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/AdPa-1/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/AdPa-1/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/AdPa-2/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/AdPa-2/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/AdPa-3/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/AdPa-3/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/D-1/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/D-1/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/D-2/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/D-2/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/D-3/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/D-3/Rep1/original

# %% [markdown]
# ### Generate movies

# %%
# Call the function
qd.fluorescence_heatmap(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    time_interval_list=time_interval_list, 
    vmax=20, 
    skip_frames=4, 
    calibration_curve_paths=calibration_curve_paths, 
    show_scalebar=False,
    custom_title=None   
    )
# Out:
# Processing AdPa-1 - Rep1:   0%|          | 0/399 [00:00<?, ?it/s]
# Processing AdPa-1 - Rep1: 100%|██████████| 399/399 [02:25<00:00,  2.75it/s]
# Processing AdPa-2 - Rep1: 100%|██████████| 399/399 [02:23<00:00,  2.79it/s]
# Processing AdPa-3 - Rep1: 100%|██████████| 399/399 [02:18<00:00,  2.88it/s]
# Processing D-1 - Rep1: 100%|██████████| 399/399 [02:21<00:00,  2.81it/s]
# Processing D-2 - Rep1: 100%|██████████| 399/399 [02:20<00:00,  2.85it/s]
# Processing D-3 - Rep1: 100%|██████████| 399/399 [02:01<00:00,  3.28it/s]

# %%
# Example usage
qd.create_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    frame_rate=5,
    skip_frames=1
    )

# %%
qd.create_combined_heatmap_movie_custom_grid(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    grid_rows=2, 
    grid_cols=3, 
    frame_rate=60,
    batch_size=50
    )
# Out:
# Creating video with duration: 6.65 seconds.
# Creating combined frames: 100%|██████████| 399/399 [02:55<00:00,  2.27it/s]
# Combined video saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/movies/combined_heatmap_movie_cy5_60fps_399frames.avi

# %%
# Call the function
qd.fluorescence_heatmap(
    data_path, 
    conditions[:], 
    subconditions, 
    channel='GFP', 
    time_interval_list=time_interval_list, 
    vmax=200, 
    skip_frames=8, 
    calibration_curve_paths=calibration_curve_paths, 
    show_scalebar=False,
    )
# Out:
# Processing AdPa-1 - Rep1: 100%|██████████| 200/200 [00:47<00:00,  4.23it/s]
# Processing AdPa-2 - Rep1: 100%|██████████| 200/200 [00:46<00:00,  4.34it/s]
# Processing AdPa-3 - Rep1:  36%|███▌      | 72/200 [00:18<00:32,  3.96it/s]
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/david-larios/git/activedrops/code/experiments/../../py_files/quadrop2.py", line 544, in process_image
#     plt.savefig(heatmap_path, bbox_inches='tight', pad_inches=0, dpi=200)
#   File "/home/david-larios/my_venv_3_11_5/lib/python3.11/site-packages/matplotlib/pyplot.py", line 1228, in savefig
#     res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/david-larios/my_venv_3_11_5/lib/python3.11/site-packages/matplotlib/figure.py", line 3395, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/home/david-larios/my_venv_3_11_5/lib/python3.11/site-packages/matplotlib/backend_bases.py", line 2204, in print_figure
#     result = print_method(
#              ^^^^^^^^^^^^^
#   File "/home/david-larios/my_venv_3_11_5/lib/python3.11/site-packages/matplotlib/backend_bases.py", line 2054, in <lambda>
#     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#                                                                  ^^^^^
#   File "/home/david-larios/my_venv_3_11_5/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py", line 496, in print_png
#     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#   File "/home/david-larios/my_venv_3_11_5/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py", line 445, in _print_pil
#     mpl.image.imsave(
#   File "/home/david-larios/my_venv_3_11_5/lib/python3.11/site-packages/matplotlib/image.py", line 1676, in imsave
#     image.save(fname, **pil_kwargs)
#   File "/home/david-larios/my_venv_3_11_5/lib/python3.11/site-packages/PIL/Image.py", line 2563, in save
#     fp = builtins.open(filename, "w+b")
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/home/david-larios/Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/movies/AdPa-3_Rep1_heatmaps_GFP/heatmap_frame_72.png'
# """
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Call the function
# ----> 2 qd.fluorescence_heatmap(
#       3     data_path,
#       4     conditions[:],
#       5     subconditions,
#       6     channel='GFP',
#       7     time_interval_list=time_interval_list,
#       8     vmax=200,
#       9     skip_frames=8,
#      10     calibration_curve_paths=calibration_curve_paths,
#      11     show_scalebar=False,
#      12     )
#
# File ~/git/activedrops/code/experiments/../../py_files/quadrop2.py:661, in fluorescence_heatmap(data_path, conditions, subconditions, channel, time_interval_list, vmax, min_frame, max_frame, skip_frames, calibration_curve_paths, show_scalebar, batch_size, custom_title)
#     657     args = [(image_file, output_directory_path, channel, slope, intercept, vmax_for_movie, time_interval, i, show_scalebar, min_frame, skip_frames, condition, subcondition)
#     658             for i, image_file in enumerate(batch_files, start=batch_start + min_frame)]
#     660 with mp.Pool(mp.cpu_count()) as pool:
# --> 661     for _ in pool.imap(process_image, args):
#     662         pbar.update(1)
#
# File /usr/local/lib/python3.11/multiprocessing/pool.py:873, in IMapIterator.next(self, timeout)
#     871 if success:
#     872     return value
# --> 873 raise value
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/david-larios/Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/movies/AdPa-3_Rep1_heatmaps_GFP/heatmap_frame_72.png'

# %%
# Example usage
qd.create_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel='GFP', 
    frame_rate=15,
    skip_frames=1
    )

# %%
qd.create_combined_heatmap_movie_custom_grid(
    data_path, 
    conditions, 
    subconditions, 
    channel='GFP', 
    grid_rows=2, 
    grid_cols=3,       
    frame_rate=15,
    batch_size=50
    )
# Out:
# Creating video with duration: 5.67 seconds.
# Creating combined frames: 100%|██████████| 85/85 [00:55<00:00,  1.52it/s]
# Combined video saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-AcSu-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/movies/combined_heatmap_movie_GFP_15fps_85frames.avi

# %%
# qd.delete_temporary_image_directories(data_path, conditions, subconditions)

# %% [markdown]
# ### Fluorescence Quantification

# %%
# Example usage
# mw_kda_list = [44.95] * len(conditions)
droplet_volume_list = [2] * len(conditions)
# protein_lengths_list = [401] * len(conditions) # last one is negative

qd.quantify_tiffiles(
    data_path, 
    conditions, 
    subconditions, 
    calibration_curve_paths, 
    droplet_volume_list, 
    time_interval_list, 
    skip_frames=1,
)
# Out:
# 2026-03-20 00:40:07,381 - INFO - Calibration concentrations (ug/ml) from filenames: [0.0, 2.0, 4.0, 9.0, 18.0, 35.0, 70.0, 140.0, 280.0]
# 2026-03-20 00:40:08,905 - INFO - ROI detected for AdPa-1-Rep1: 1,963,486 px (eff. radius 791 px)
# 2026-03-20 00:40:09,980 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_AdPa-1_Rep1.png
# Calculating intensities for AdPa-1 - Rep1: 100%|██████████| 1596/1596 [00:10<00:00, 150.55it/s]
# 2026-03-20 00:40:21,328 - INFO - ROI detected for AdPa-2-Rep1: 1,870,963 px (eff. radius 772 px)
# 2026-03-20 00:40:22,456 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_AdPa-2_Rep1.png
# Calculating intensities for AdPa-2 - Rep1: 100%|██████████| 1595/1595 [00:08<00:00, 184.06it/s]
# 2026-03-20 00:40:31,883 - INFO - ROI detected for AdPa-3-Rep1: 1,774,639 px (eff. radius 752 px)
# 2026-03-20 00:40:33,216 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_AdPa-3_Rep1.png
# Calculating intensities for AdPa-3 - Rep1: 100%|██████████| 1596/1596 [00:08<00:00, 191.13it/s]
# 2026-03-20 00:40:42,283 - INFO - ROI detected for D-1-Rep1: 1,960,827 px (eff. radius 790 px)
# 2026-03-20 00:40:43,656 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_D-1_Rep1.png
# Calculating intensities for D-1 - Rep1: 100%|██████████| 1596/1596 [00:08<00:00, 195.75it/s]
# 2026-03-20 00:40:52,646 - INFO - ROI detected for D-2-Rep1: 1,886,224 px (eff. radius 775 px)
# 2026-03-20 00:40:53,887 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_D-2_Rep1.png
# Calculating intensities for D-2 - Rep1: 100%|██████████| 1596/1596 [00:08<00:00, 189.91it/s]
# 2026-03-20 00:41:03,148 - INFO - ROI detected for D-3-Rep1: 1,542,587 px (eff. radius 701 px)
# 2026-03-20 00:41:04,477 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_D-3_Rep1.png
# Calculating intensities for D-3 - Rep1: 100%|██████████| 1596/1596 [00:08<00:00, 192.12it/s]
# ('../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/combined_expression.csv',
#  '../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/mean_expression.csv')

# %% [markdown]
# ### PIV pre-processing

# %%
conditions[1:3]
# Out:
# ['AdPa-2', 'AdPa-3']

# %%
qd.split_tiffs(data_path, conditions[1:3], subconditions, channel='cy5', file_interval=4)
# Out:
# Copied every 4th f'cy5' file from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/AdPa-2/Rep1/original into ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/AdPa-2/Rep1/cy5-4x.
# Copied every 4th f'cy5' file from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/AdPa-3/Rep1/original into ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/AdPa-3/Rep1/cy5-4x.

# %% [markdown]
# ### PIV

# %%
# Define feature limits and other parameters
v = 2E-7
velocity_limits = (0, v)
other_limits = (-0.0005, 0.0005)
skip_frames = 1 ### CHANGE THIS TO SKIP FRAMES


velocity_limits = (None, None)
other_limits = (None, None)


feature_limits = {
    # 'u [m/s]': (-v, v), 
    # 'v [m/s]': (-v, v), 
    # 'data type [-]': (None, None),
    'velocity magnitude [m/s]': velocity_limits,
    'vorticity [1/s]': other_limits,
    'divergence [1/s]': other_limits,
    # 'dcev [1]': (0, 250),
    'shear [1/s]': other_limits,
    'strain [1/s]': other_limits,
    'vector direction [degrees]': (-180, 180),
}


# Features for PCA and plotting
features_pca = [
    "vorticity [1/s]_mean",
    "velocity magnitude [um/s]",
    "distance [m]_mean",
    "divergence [1/s]_mean",
    "shear [1/s]_mean",
    "strain [1/s]_mean",
    "correlation length [um]", 
    "power [W]_mean",
    "work [J]",
]

# %%
time_interval_list = [80, 80, 80, 20, 20, 20]  # time intervals in seconds between frames for each condition


# Process PIV data
qd.process_piv_data(
    data_path, 
    conditions,    
    subconditions, 
    feature_limits, 
    time_interval_list, 
    min_frame=0, 
    max_frame=None, 
    skip_frames=1, 
    plot_autocorrelation=False, 
    frame_rate=1, 
    heatmaps=False
    )
# Out:
# Processing PIV data:   0%|          | 0/6 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  17%|█▋        | 1/6 [00:07<00:37,  7.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  33%|███▎      | 2/6 [00:11<00:22,  5.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  50%|█████     | 3/6 [00:15<00:14,  4.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  67%|██████▋   | 4/6 [00:27<00:15,  7.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  83%|████████▎ | 5/6 [00:37<00:08,  8.61s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data: 100%|██████████| 6/6 [00:47<00:00,  7.91s/it]

# %%
# Plot features and PCA
qd.plot_PIV_all(
    data_path, 
    conditions,
    subconditions, 
    features_pca, 
    min_frame=0, 
    max_frame=None
    )
# Out:
# Plotting PIV features: 100%|██████████| 6/6 [00:14<00:00,  2.46s/it]
# Plotting averaged PIV features: 100%|██████████| 6/6 [00:10<00:00,  1.78s/it]
# Collecting PIV data: 100%|██████████| 6/6 [00:00<00:00, 235.75it/s]

# %% [markdown]
# ### Expression + PIV

# %%
# Combine the data and save it to the "output_data" directory
qd.combine_averaged_dataframes(data_path, conditions, subconditions)
# Out:
# Conditions: 100%|██████████| 6/6 [00:00<00:00, 206.70it/s]
# Combined DataFrame saved to: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/combined_PIV.csv

# %%
qd.merge_expression_piv_data(data_path)
# Out:
# Merged DataFrame saved to: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031726-AdPa-D-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/merged_expression_PIV.csv

# %%
# x_column = "time (h)"  # Example x-axis column
# y_column = "Protein Concentration_nM"  # Example y-axis column


# x_column = "Protein Concentration_nM"  # Example y-axis column
# y_column = "velocity magnitude [m/s]_mean"  # Example y-axis column

# x_column = "time (h)"  # Example x-axis column
# y_column = "velocity magnitude [m/s]_mean"  # Example y-axis column

# x_column = "time (h)"  # Example x-axis column
# y_column = "power [W]_mean"  # Example y-axis column

# x_column = "time (h)"  # Example x-axis column
# y_column = "work [J]_mean"  # Example y-axis column

x_column = "time (h)"  # Example x-axis column
y_column = "distance [m]_mean"  # Example y-axis column


qd.plot_expression_piv(
    data_path,
    conditions,
    x_column, 
    y_column, 
    sigma_x=0.1, 
    sigma_y=10, 
    x_log=False, 
    y_log=True, 
    min_frame=0, 
    max_frame=None, 
    individual_plots=False
    )

# %%
# List of features for PCA
features_pca = [
    "vorticity [1/s]_mean",
    "velocity magnitude [m/s]_mean",
    "distance [m]_mean",
    "divergence [1/s]_mean",
    "shear [1/s]_mean",
    "strain [1/s]_mean",
    "correlation length [m]_mean", 
    "power [W]_mean",
    "work [J]_mean",
    'vector direction [degrees]_mean',
    "Protein Concentration_nM", 
    'time (min)'
]

# Run PCA and save plot (with all conditions and subconditions in the same plot)
qd.plot_pca_expression_piv(data_path, conditions=conditions, subconditions=subconditions, features=features_pca, sigma=1)

# %%
# Example usage
qd.delete_outputs(data_path, conditions, subconditions, output_dirs=None)
