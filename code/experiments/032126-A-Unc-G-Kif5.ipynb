# %%
## Import relevant libraries
import sys
import glob

sys.path.append('../../py_files/')
import quadrop2 as qd

qd.set_plotting_style()

# %% [markdown]
# ### Data pre-procesing

# %%
# # Example usage
# base_dir = "../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-AcSu-3x/"
# qd.consolidate_images(base_dir)

# %%
# Example usage
data_path = "../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/"

calibration_curve_paths = sorted(glob.glob("../../../../Thomson Lab Dropbox/David Larios/activedrops/calibration_curve/***ugml.tif"))

conditions_dict = {
    "K401-1": "Pos0",
    "K401-2": "Pos1",
    "K401-3": "Pos2",
    "Unc-1": "Pos3",
    "Unc-2": "Pos4",
    "Unc-3": "Pos5",
    "G-1": "Pos6",
    "G-2": "Pos7",
    "G-3": "Pos8",
    "Kif5-1": "Pos9",
    "Kif5-2": "Pos10",
    "Kif5-3": "Pos11",

}

# Organize PosX folders into condition folders
qd.organize_conditions(data_path, conditions_dict)

# Now run the existing functions to reorganize the tiffs and rename the folders
conditions, subconditions = qd.prepare_conditions(data_path)
time_interval_list = [60] * len(conditions)  # time intervals in seconds between frames for each condition

subconditions = ['Rep1']
print("Conditions:", conditions)
print("Subconditions:", subconditions)
# Out:
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Pos0 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Pos1 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Pos2 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Pos3 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Pos4 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Pos5 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Pos6 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Pos7 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Pos8 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Pos9 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Pos10 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Pos11 does not exist. Skipping.
# Conditions: ['G-1', 'G-2', 'G-3', 'K401-1', 'K401-2', 'K401-3', 'Kif5-1', 'Kif5-2', 'Kif5-3', 'Unc-1', 'Unc-2', 'Unc-3']
# Subconditions: ['Rep1']

# %%
qd.reorgTiffsToOriginal(data_path, conditions, subconditions)
# Out:
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/G-1/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/G-1/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/G-2/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/G-2/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/G-3/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/G-3/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/K401-1/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/K401-1/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/K401-2/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/K401-2/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/K401-3/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/K401-3/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Kif5-1/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Kif5-1/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Kif5-2/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Kif5-2/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Kif5-3/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Kif5-3/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Unc-1/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Unc-1/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Unc-2/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Unc-2/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Unc-3/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/Unc-3/Rep1/original

# %% [markdown]
# ### Generate movies

# %%
# Call the function
qd.fluorescence_heatmap(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    time_interval_list=time_interval_list, 
    vmax=20, 
    skip_frames=4, 
    calibration_curve_paths=calibration_curve_paths, 
    show_scalebar=False,
    custom_title=None   
    )
# Out:
# Processing G-1 - Rep1:   0%|          | 0/376 [00:00<?, ?it/s]
# Processing G-1 - Rep1: 100%|██████████| 376/376 [01:03<00:00,  5.94it/s]
# Processing G-2 - Rep1: 100%|██████████| 376/376 [01:03<00:00,  5.94it/s]
# Processing G-3 - Rep1: 100%|██████████| 376/376 [01:04<00:00,  5.79it/s]
# Processing K401-1 - Rep1: 100%|██████████| 376/376 [01:02<00:00,  5.97it/s]
# Processing K401-2 - Rep1: 100%|██████████| 376/376 [01:02<00:00,  6.05it/s]
# Processing K401-3 - Rep1: 100%|██████████| 376/376 [01:02<00:00,  5.97it/s]
# Processing Kif5-1 - Rep1: 100%|██████████| 376/376 [01:02<00:00,  6.00it/s]
# Processing Kif5-2 - Rep1: 100%|██████████| 376/376 [01:02<00:00,  6.01it/s]
# Processing Kif5-3 - Rep1: 100%|██████████| 376/376 [01:03<00:00,  5.95it/s]
# Processing Unc-1 - Rep1: 100%|██████████| 376/376 [01:02<00:00,  5.97it/s]
# Processing Unc-2 - Rep1: 100%|██████████| 376/376 [01:03<00:00,  5.95it/s]
# Processing Unc-3 - Rep1: 100%|██████████| 376/376 [01:03<00:00,  5.96it/s]

# %%
# Example usage
qd.create_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    frame_rate=5,
    skip_frames=1
    )

# %%
qd.create_combined_heatmap_movie_custom_grid(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    grid_rows=4, 
    grid_cols=3, 
    frame_rate=30,
    batch_size=50
    )
# Out:
# Creating video with duration: 12.53 seconds.
# Creating combined frames: 100%|██████████| 376/376 [05:15<00:00,  1.19it/s]
# Combined video saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/movies/combined_heatmap_movie_cy5_30fps_376frames.avi

# %%
# Call the function
qd.fluorescence_heatmap(
    data_path, 
    conditions[:], 
    subconditions, 
    channel='GFP', 
    time_interval_list=time_interval_list, 
    vmax=200, 
    skip_frames=8, 
    calibration_curve_paths=calibration_curve_paths, 
    show_scalebar=False,
    )
# Out:
# Processing G-1 - Rep1: 100%|██████████| 188/188 [00:35<00:00,  5.34it/s]
# Processing G-2 - Rep1: 100%|██████████| 188/188 [00:34<00:00,  5.51it/s]
# Processing G-3 - Rep1: 100%|██████████| 188/188 [00:36<00:00,  5.16it/s]
# Processing K401-1 - Rep1: 100%|██████████| 188/188 [00:35<00:00,  5.25it/s]
# Processing K401-2 - Rep1: 100%|██████████| 188/188 [00:35<00:00,  5.26it/s]
# Processing K401-3 - Rep1: 100%|██████████| 188/188 [00:34<00:00,  5.50it/s]
# Processing Kif5-1 - Rep1: 100%|██████████| 188/188 [00:33<00:00,  5.64it/s]
# Processing Kif5-2 - Rep1: 100%|██████████| 188/188 [00:33<00:00,  5.66it/s]
# Processing Kif5-3 - Rep1: 100%|██████████| 188/188 [00:32<00:00,  5.71it/s]
# Processing Unc-1 - Rep1: 100%|██████████| 188/188 [00:32<00:00,  5.71it/s]
# Processing Unc-2 - Rep1: 100%|██████████| 188/188 [00:33<00:00,  5.64it/s]
# Processing Unc-3 - Rep1: 100%|██████████| 188/188 [00:33<00:00,  5.64it/s]

# %%
# Example usage
qd.create_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel='GFP', 
    frame_rate=15,
    skip_frames=1
    )

# %%
qd.create_combined_heatmap_movie_custom_grid(
    data_path, 
    conditions, 
    subconditions, 
    channel='GFP', 
    grid_rows=4, 
    grid_cols=3,       
    frame_rate=15,
    batch_size=50
    )
# Out:
# Creating video with duration: 12.53 seconds.
# Creating combined frames: 100%|██████████| 188/188 [02:40<00:00,  1.17it/s]
# Combined video saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/movies/combined_heatmap_movie_GFP_15fps_188frames.avi

# %%
# qd.delete_temporary_image_directories(data_path, conditions, subconditions)

# %% [markdown]
# ### Fluorescence Quantification

# %%
# Example usage
# mw_kda_list = [44.95] * len(conditions)
droplet_volume_list = [2] * len(conditions)
# protein_lengths_list = [401] * len(conditions) # last one is negative

qd.quantify_tiffiles(
    data_path, 
    conditions, 
    subconditions, 
    calibration_curve_paths, 
    droplet_volume_list, 
    time_interval_list, 
    skip_frames=1,
)
# Out:
# 2026-03-24 02:09:55,351 - INFO - Calibration concentrations (ug/ml) from filenames: [0.0, 9.0, 18.0, 35.0, 70.0, 140.0]
# 2026-03-24 02:09:56,574 - INFO - ROI detected for G-1-Rep1: 1,964,204 px (eff. radius 791 px)
# 2026-03-24 02:09:57,552 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_G-1_Rep1.png
# Calculating intensities for G-1 - Rep1: 100%|██████████| 1503/1503 [00:07<00:00, 211.92it/s]
# 2026-03-24 02:10:05,318 - INFO - ROI detected for G-2-Rep1: 1,837,137 px (eff. radius 765 px)
# 2026-03-24 02:10:06,309 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_G-2_Rep1.png
# Calculating intensities for G-2 - Rep1: 100%|██████████| 1503/1503 [00:06<00:00, 218.04it/s]
# 2026-03-24 02:10:13,943 - INFO - ROI detected for G-3-Rep1: 1,978,768 px (eff. radius 794 px)
# 2026-03-24 02:10:15,064 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_G-3_Rep1.png
# Calculating intensities for G-3 - Rep1: 100%|██████████| 1503/1503 [00:07<00:00, 196.37it/s]
# 2026-03-24 02:10:23,439 - INFO - ROI detected for K401-1-Rep1: 1,868,103 px (eff. radius 771 px)
# 2026-03-24 02:10:24,526 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_K401-1_Rep1.png
# Calculating intensities for K401-1 - Rep1: 100%|██████████| 1503/1503 [00:07<00:00, 210.58it/s]
# 2026-03-24 02:10:32,360 - INFO - ROI detected for K401-2-Rep1: 1,630,273 px (eff. radius 720 px)
# 2026-03-24 02:10:33,405 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_K401-2_Rep1.png
# Calculating intensities for K401-2 - Rep1: 100%|██████████| 1502/1502 [00:06<00:00, 238.10it/s]
# 2026-03-24 02:10:40,427 - INFO - ROI detected for K401-3-Rep1: 1,743,571 px (eff. radius 745 px)
# 2026-03-24 02:10:41,517 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_K401-3_Rep1.png
# Calculating intensities for K401-3 - Rep1: 100%|██████████| 1503/1503 [00:06<00:00, 229.67it/s]
# 2026-03-24 02:10:48,808 - INFO - ROI detected for Kif5-1-Rep1: 1,847,906 px (eff. radius 767 px)
# 2026-03-24 02:10:49,858 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_Kif5-1_Rep1.png
# Calculating intensities for Kif5-1 - Rep1: 100%|██████████| 1503/1503 [00:06<00:00, 232.65it/s]
# 2026-03-24 02:10:57,069 - INFO - ROI detected for Kif5-2-Rep1: 1,864,102 px (eff. radius 770 px)
# 2026-03-24 02:10:58,105 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_Kif5-2_Rep1.png
# Calculating intensities for Kif5-2 - Rep1: 100%|██████████| 1503/1503 [00:06<00:00, 235.30it/s]
# 2026-03-24 02:11:05,232 - INFO - ROI detected for Kif5-3-Rep1: 1,679,413 px (eff. radius 731 px)
# 2026-03-24 02:11:06,298 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_Kif5-3_Rep1.png
# Calculating intensities for Kif5-3 - Rep1: 100%|██████████| 1503/1503 [00:07<00:00, 200.76it/s]
# 2026-03-24 02:11:14,522 - INFO - ROI detected for Unc-1-Rep1: 1,724,521 px (eff. radius 741 px)
# 2026-03-24 02:11:15,591 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_Unc-1_Rep1.png
# Calculating intensities for Unc-1 - Rep1: 100%|██████████| 1503/1503 [00:07<00:00, 207.23it/s]
# 2026-03-24 02:11:23,592 - INFO - ROI detected for Unc-2-Rep1: 1,800,040 px (eff. radius 757 px)
# 2026-03-24 02:11:24,741 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_Unc-2_Rep1.png
# Calculating intensities for Unc-2 - Rep1: 100%|██████████| 1503/1503 [00:07<00:00, 211.33it/s]
# 2026-03-24 02:11:32,616 - INFO - ROI detected for Unc-3-Rep1: 1,757,562 px (eff. radius 748 px)
# 2026-03-24 02:11:33,712 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_Unc-3_Rep1.png
# Calculating intensities for Unc-3 - Rep1: 100%|██████████| 1503/1503 [00:06<00:00, 231.94it/s]
# ('../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/combined_expression.csv',
#  '../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/032126-A-Unc-G-Kif5/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/mean_expression.csv')

# %% [markdown]
# ### PIV pre-processing

# %%
qd.split_tiffs(data_path, conditions, subconditions, channel='cy5', file_interval=1)
# Out:
# Copied every 1th f'cy5' file from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031526-TiLa_DiPu-3x/3ulTXTL-1ulMTs-0p5ulDNA_3/DiPu-1/Rep1/original into ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031526-TiLa_DiPu-3x/3ulTXTL-1ulMTs-0p5ulDNA_3/DiPu-1/Rep1/cy5-1x.
# Copied every 1th f'cy5' file from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031526-TiLa_DiPu-3x/3ulTXTL-1ulMTs-0p5ulDNA_3/DiPu-2/Rep1/original into ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031526-TiLa_DiPu-3x/3ulTXTL-1ulMTs-0p5ulDNA_3/DiPu-2/Rep1/cy5-1x.
# Copied every 1th f'cy5' file from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031526-TiLa_DiPu-3x/3ulTXTL-1ulMTs-0p5ulDNA_3/DiPu-3/Rep1/original into ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031526-TiLa_DiPu-3x/3ulTXTL-1ulMTs-0p5ulDNA_3/DiPu-3/Rep1/cy5-1x.
# Copied every 1th f'cy5' file from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031526-TiLa_DiPu-3x/3ulTXTL-1ulMTs-0p5ulDNA_3/TiLa-1/Rep1/original into ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031526-TiLa_DiPu-3x/3ulTXTL-1ulMTs-0p5ulDNA_3/TiLa-1/Rep1/cy5-1x.
# Copied every 1th f'cy5' file from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031526-TiLa_DiPu-3x/3ulTXTL-1ulMTs-0p5ulDNA_3/TiLa-2/Rep1/original into ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031526-TiLa_DiPu-3x/3ulTXTL-1ulMTs-0p5ulDNA_3/TiLa-2/Rep1/cy5-1x.
# Copied every 1th f'cy5' file from ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031526-TiLa_DiPu-3x/3ulTXTL-1ulMTs-0p5ulDNA_3/TiLa-3/Rep1/original into ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031526-TiLa_DiPu-3x/3ulTXTL-1ulMTs-0p5ulDNA_3/TiLa-3/Rep1/cy5-1x.

# %% [markdown]
# ### PIV

# %%
# Define feature limits and other parameters
v = 2E-7
velocity_limits = (0, v)
other_limits = (-0.0005, 0.0005)
skip_frames = 1 ### CHANGE THIS TO SKIP FRAMES


velocity_limits = (None, None)
other_limits = (None, None)


feature_limits = {
    # 'u [m/s]': (-v, v), 
    # 'v [m/s]': (-v, v), 
    # 'data type [-]': (None, None),
    'velocity magnitude [m/s]': velocity_limits,
    'vorticity [1/s]': other_limits,
    'divergence [1/s]': other_limits,
    # 'dcev [1]': (0, 250),
    'shear [1/s]': other_limits,
    'strain [1/s]': other_limits,
    'vector direction [degrees]': (-180, 180),
}


# Features for PCA and plotting
features_pca = [
    "vorticity [1/s]_mean",
    "velocity magnitude [um/s]",
    "distance [m]_mean",
    "divergence [1/s]_mean",
    "shear [1/s]_mean",
    "strain [1/s]_mean",
    "correlation length [um]", 
    "power [W]_mean",
    "work [J]",
]

# %%
# time_interval_list = [60]  # time intervals in seconds between frames for each condition


# Process PIV data
qd.process_piv_data(
    data_path, 
    conditions,    
    subconditions, 
    feature_limits, 
    time_interval_list, 
    min_frame=0, 
    max_frame=None, 
    skip_frames=1, 
    plot_autocorrelation=False, 
    frame_rate=1, 
    heatmaps=False
    )
# Out:
# Processing PIV data:   0%|          | 0/6 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  17%|█▋        | 1/6 [00:07<00:39,  7.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  33%|███▎      | 2/6 [00:14<00:28,  7.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  50%|█████     | 3/6 [00:20<00:19,  6.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  67%|██████▋   | 4/6 [00:25<00:11,  5.81s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  83%|████████▎ | 5/6 [00:29<00:05,  5.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data: 100%|██████████| 6/6 [00:35<00:00,  5.84s/it]

# %%
# Plot features and PCA
qd.plot_PIV_all(
    data_path, 
    conditions,
    subconditions, 
    features_pca, 
    min_frame=0, 
    max_frame=None
    )
# Out:
# Plotting PIV features: 100%|██████████| 6/6 [00:15<00:00,  2.59s/it]
# Plotting averaged PIV features: 100%|██████████| 6/6 [00:09<00:00,  1.66s/it]
# Collecting PIV data: 100%|██████████| 6/6 [00:00<00:00, 249.28it/s]

# %% [markdown]
# ### Expression + PIV

# %%
# Combine the data and save it to the "output_data" directory
qd.combine_averaged_dataframes(data_path, conditions, subconditions)
# Out:
# Conditions: 100%|██████████| 6/6 [00:00<00:00, 222.32it/s]
# Combined DataFrame saved to: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031526-TiLa_DiPu-3x/3ulTXTL-1ulMTs-0p5ulDNA_3/output_data/combined_PIV.csv

# %%
qd.merge_expression_piv_data(data_path)
# Out:
# Merged DataFrame saved to: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/031526-TiLa_DiPu-3x/3ulTXTL-1ulMTs-0p5ulDNA_3/output_data/merged_expression_PIV.csv

# %%
# x_column = "time (h)"  # Example x-axis column
# y_column = "Protein Concentration_nM"  # Example y-axis column


# x_column = "Protein Concentration_nM"  # Example y-axis column
# y_column = "velocity magnitude [m/s]_mean"  # Example y-axis column

# x_column = "time (h)"  # Example x-axis column
# y_column = "velocity magnitude [m/s]_mean"  # Example y-axis column

# x_column = "time (h)"  # Example x-axis column
# y_column = "power [W]_mean"  # Example y-axis column

# x_column = "time (h)"  # Example x-axis column
# y_column = "work [J]_mean"  # Example y-axis column

x_column = "time (h)"  # Example x-axis column
y_column = "distance [m]_mean"  # Example y-axis column


qd.plot_expression_piv(
    data_path,
    conditions,
    x_column, 
    y_column, 
    sigma_x=0.1, 
    sigma_y=10, 
    x_log=False, 
    y_log=True, 
    min_frame=0, 
    max_frame=None, 
    individual_plots=False
    )

# %%
# List of features for PCA
features_pca = [
    "vorticity [1/s]_mean",
    "velocity magnitude [m/s]_mean",
    "distance [m]_mean",
    "divergence [1/s]_mean",
    "shear [1/s]_mean",
    "strain [1/s]_mean",
    "correlation length [m]_mean", 
    "power [W]_mean",
    "work [J]_mean",
    'vector direction [degrees]_mean',
    "Protein Concentration_nM", 
    'time (min)'
]

# Run PCA and save plot (with all conditions and subconditions in the same plot)
qd.plot_pca_expression_piv(data_path, conditions=conditions, subconditions=subconditions, features=features_pca, sigma=1)

# %%
# Example usage
qd.delete_outputs(data_path, conditions, subconditions, output_dirs=None)
