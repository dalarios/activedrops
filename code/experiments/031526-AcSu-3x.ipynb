# %%
## Import relevant libraries
import sys
import glob

sys.path.append('../../py_files/')
import quadrop2 as qd

qd.set_plotting_style()

# %% [markdown]
# ### Data pre-procesing

# %%
# # Example usage
# base_dir = "../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-AcSu-3x/"
# qd.consolidate_images(base_dir)

# %%
# Example usage
data_path = "../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-AcSu-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/"

calibration_curve_paths = sorted(glob.glob("../../../../Thomson Lab Dropbox/David Larios/activedrops/calibration-50ms/***ugml.tif"))

conditions_dict = {
    "AcSu-1": "Pos0",
    "AcSu-2": "Pos1",
    "AcSu-3": "Pos2",
}

# Organize PosX folders into condition folders
qd.organize_conditions(data_path, conditions_dict)

# Now run the existing functions to reorganize the tiffs and rename the folders
conditions, subconditions = qd.prepare_conditions(data_path)
time_interval_list = [30] * len(conditions)  # time intervals in seconds between frames for each condition

subconditions = ['Rep1']
print("Conditions:", conditions)
print("Subconditions:", subconditions)
# Out:
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-AcSu-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/Pos0 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-AcSu-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/Pos1 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-AcSu-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/Pos2 does not exist. Skipping.
# Conditions: ['AcSu-1', 'AcSu-2', 'AcSu-3']
# Subconditions: ['Rep1']

# %%
qd.reorgTiffsToOriginal(data_path, conditions, subconditions)

# %% [markdown]
# ### Generate movies

# %%
# Call the function
qd.fluorescence_heatmap(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    time_interval_list=time_interval_list, 
    vmax=16, 
    skip_frames=1, 
    calibration_curve_paths=calibration_curve_paths, 
    show_scalebar=False,
    custom_title=None   
    )
# Out:
# Processing AcSu-1 - Rep1:   0%|          | 0/678 [00:00<?, ?it/s]
# Processing AcSu-1 - Rep1: 100%|██████████| 678/678 [02:18<00:00,  4.89it/s]
# Processing AcSu-2 - Rep1: 100%|██████████| 678/678 [02:15<00:00,  5.01it/s]
# Processing AcSu-3 - Rep1: 100%|██████████| 678/678 [02:24<00:00,  4.68it/s]

# %%
# Example usage
qd.create_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    frame_rate=5,
    skip_frames=1
    )

# %%
qd.create_combined_heatmap_movie_custom_grid(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    grid_rows=1, 
    grid_cols=3, 
    frame_rate=60,
    batch_size=50
    )
# Out:
# Creating video with duration: 11.30 seconds.
# Creating combined frames: 100%|██████████| 678/678 [07:02<00:00,  1.60it/s]
# Combined video saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-AcSu-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/movies/combined_heatmap_movie_cy5_60fps_678frames.avi

# %%
# Call the function
qd.fluorescence_heatmap(
    data_path, 
    conditions[:], 
    subconditions, 
    channel='GFP', 
    time_interval_list=time_interval_list, 
    vmax=200, 
    skip_frames=8, 
    calibration_curve_paths=calibration_curve_paths, 
    show_scalebar=False,
    )
# Out:
# Processing AcSu-1 - Rep1: 100%|██████████| 85/85 [01:14<00:00,  1.14it/s]
# Processing AcSu-2 - Rep1: 100%|██████████| 85/85 [01:15<00:00,  1.13it/s]
# Processing AcSu-3 - Rep1: 100%|██████████| 85/85 [01:17<00:00,  1.10it/s]

# %%
# Example usage
qd.create_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel='GFP', 
    frame_rate=15,
    skip_frames=1
    )

# %%
qd.create_combined_heatmap_movie_custom_grid(
    data_path, 
    conditions, 
    subconditions, 
    channel='GFP', 
    grid_rows=1, 
    grid_cols=3,       
    frame_rate=15,
    batch_size=50
    )
# Out:
# Creating video with duration: 5.67 seconds.
# Creating combined frames: 100%|██████████| 85/85 [00:55<00:00,  1.52it/s]
# Combined video saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-AcSu-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/movies/combined_heatmap_movie_GFP_15fps_85frames.avi

# %%
# qd.delete_temporary_image_directories(data_path, conditions, subconditions)

# %% [markdown]
# ### Fluorescence Quantification

# %%
# Example usage
# mw_kda_list = [44.95] * len(conditions)
droplet_volume_list = [2] * len(conditions)
# protein_lengths_list = [401] * len(conditions) # last one is negative

qd.quantify_tiffiles(
    data_path, 
    conditions, 
    subconditions, 
    calibration_curve_paths, 
    droplet_volume_list, 
    time_interval_list, 
    skip_frames=1,
)
# Out:
# 2026-03-19 18:01:10,293 - INFO - Calibration concentrations (ug/ml) from filenames: [0.0, 2.0, 4.0, 9.0, 18.0, 35.0, 70.0, 140.0, 280.0]
# 2026-03-19 18:01:11,700 - INFO - ROI detected for AcSu-1-Rep1: 2,067,432 px (eff. radius 811 px)
# 2026-03-19 18:01:12,532 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-AcSu-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_AcSu-1_Rep1.png
# Calculating intensities for AcSu-1 - Rep1: 100%|██████████| 678/678 [00:01<00:00, 348.77it/s]
# 2026-03-19 18:01:15,122 - INFO - ROI detected for AcSu-2-Rep1: 1,875,174 px (eff. radius 773 px)
# 2026-03-19 18:01:15,903 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-AcSu-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_AcSu-2_Rep1.png
# Calculating intensities for AcSu-2 - Rep1: 100%|██████████| 678/678 [00:02<00:00, 281.96it/s]
# 2026-03-19 18:01:18,922 - INFO - ROI detected for AcSu-3-Rep1: 1,870,094 px (eff. radius 772 px)
# 2026-03-19 18:01:19,699 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-AcSu-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/roi_diagnostic_AcSu-3_Rep1.png
# Calculating intensities for AcSu-3 - Rep1: 100%|██████████| 678/678 [00:02<00:00, 325.33it/s]
# ('../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-AcSu-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/combined_expression.csv',
#  '../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-AcSu-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/mean_expression.csv')

# %% [markdown]
# ### PIV pre-processing

# %%
qd.split_tiffs(data_path, conditions, subconditions, channel='cy5', file_interval=1)

# %% [markdown]
# ### PIV

# %%
# Define feature limits and other parameters
v = 2E-7
velocity_limits = (0, v)
other_limits = (-0.0005, 0.0005)
skip_frames = 1 ### CHANGE THIS TO SKIP FRAMES


velocity_limits = (None, None)
other_limits = (None, None)


feature_limits = {
    # 'u [m/s]': (-v, v), 
    # 'v [m/s]': (-v, v), 
    # 'data type [-]': (None, None),
    'velocity magnitude [m/s]': velocity_limits,
    'vorticity [1/s]': other_limits,
    'divergence [1/s]': other_limits,
    # 'dcev [1]': (0, 250),
    'shear [1/s]': other_limits,
    'strain [1/s]': other_limits,
    'vector direction [degrees]': (-180, 180),
}


# Features for PCA and plotting
features_pca = [
    "vorticity [1/s]_mean",
    "velocity magnitude [um/s]",
    "distance [m]_mean",
    "divergence [1/s]_mean",
    "shear [1/s]_mean",
    "strain [1/s]_mean",
    "correlation length [um]", 
    "power [W]_mean",
    "work [J]",
]

# %%
# time_interval_list = [60]  # time intervals in seconds between frames for each condition


# Process PIV data
qd.process_piv_data(
    data_path, 
    conditions,    
    subconditions, 
    feature_limits, 
    time_interval_list, 
    min_frame=0, 
    max_frame=None, 
    skip_frames=1, 
    plot_autocorrelation=False, 
    frame_rate=1, 
    heatmaps=False
    )
# Out:
# Processing PIV data:   0%|          | 0/3 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  33%|███▎      | 1/3 [00:02<00:04,  2.24s/it]
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  67%|██████▋   | 2/3 [00:04<00:02,  2.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data: 100%|██████████| 3/3 [00:08<00:00,  2.86s/it]

# %%
# Plot features and PCA
qd.plot_PIV_all(
    data_path, 
    conditions,
    subconditions, 
    features_pca, 
    min_frame=0, 
    max_frame=None
    )
# Out:
# Plotting PIV features: 100%|██████████| 3/3 [00:10<00:00,  3.44s/it]
# Plotting averaged PIV features: 100%|██████████| 3/3 [00:07<00:00,  2.61s/it]
# Collecting PIV data: 100%|██████████| 3/3 [00:00<00:00, 88.59it/s]

# %% [markdown]
# ### Expression + PIV

# %%
# Combine the data and save it to the "output_data" directory
qd.combine_averaged_dataframes(data_path, conditions, subconditions)
# Out:
# Conditions: 100%|██████████| 3/3 [00:00<00:00, 124.44it/s]
# Combined DataFrame saved to: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-AcSu-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/combined_PIV.csv

# %%
qd.merge_expression_piv_data(data_path)
# Out:
# Merged DataFrame saved to: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-AcSu-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/merged_expression_PIV.csv

# %%
# x_column = "time (h)"  # Example x-axis column
# y_column = "Protein Concentration_nM"  # Example y-axis column


# x_column = "Protein Concentration_nM"  # Example y-axis column
# y_column = "velocity magnitude [m/s]_mean"  # Example y-axis column

# x_column = "time (h)"  # Example x-axis column
# y_column = "velocity magnitude [m/s]_mean"  # Example y-axis column

# x_column = "time (h)"  # Example x-axis column
# y_column = "power [W]_mean"  # Example y-axis column

# x_column = "time (h)"  # Example x-axis column
# y_column = "work [J]_mean"  # Example y-axis column

x_column = "time (h)"  # Example x-axis column
y_column = "distance [m]_mean"  # Example y-axis column


qd.plot_expression_piv(
    data_path,
    conditions,
    x_column, 
    y_column, 
    sigma_x=0.1, 
    sigma_y=10, 
    x_log=False, 
    y_log=True, 
    min_frame=0, 
    max_frame=None, 
    individual_plots=False
    )

# %%
# List of features for PCA
features_pca = [
    "vorticity [1/s]_mean",
    "velocity magnitude [m/s]_mean",
    "distance [m]_mean",
    "divergence [1/s]_mean",
    "shear [1/s]_mean",
    "strain [1/s]_mean",
    "correlation length [m]_mean", 
    "power [W]_mean",
    "work [J]_mean",
    'vector direction [degrees]_mean',
    "Protein Concentration_nM", 
    'time (min)'
]

# Run PCA and save plot (with all conditions and subconditions in the same plot)
qd.plot_pca_expression_piv(data_path, conditions=conditions, subconditions=subconditions, features=features_pca, sigma=1)

# %%
# Example usage
qd.delete_outputs(data_path, conditions, subconditions, output_dirs=None)
