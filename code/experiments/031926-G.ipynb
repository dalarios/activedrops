# %%
## Import relevant libraries
import sys
import glob

sys.path.append('../../py_files/')
import quadrop2 as qd

qd.set_plotting_style()

# %% [markdown]
# ### Data pre-procesing

# %%
# # Example usage
# base_dir = "../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-AcSu-3x/"
# qd.consolidate_images(base_dir)

# %%
# Example usage
data_path = "../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/"

calibration_curve_paths = sorted(glob.glob("../../../../Thomson Lab Dropbox/David Larios/activedrops/calibration-50ms/***ugml.tif"))

conditions_dict = {
    "G-1": "Pos12",
    "G-2": "Pos13",
    "G-3": "Pos14",
}

# Organize PosX folders into condition folders
qd.organize_conditions(data_path, conditions_dict)

# Now run the existing functions to reorganize the tiffs and rename the folders
conditions, subconditions = qd.prepare_conditions(data_path)
time_interval_list = [50] * len(conditions)  # time intervals in seconds between frames for each condition

subconditions = ['Rep1']
print("Conditions:", conditions)
print("Subconditions:", subconditions)
# Out:
# Conditions: ['G-1', 'G-2', 'G-3']
# Subconditions: ['Rep1']

# %%
qd.reorgTiffsToOriginal(data_path, conditions, subconditions)
# Out:
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/G-1/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/G-1/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/G-2/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/G-2/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/G-3/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/G-3/Rep1/original

# %% [markdown]
# ### Generate movies

# %%
# Call the function
qd.fluorescence_heatmap(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    time_interval_list=time_interval_list, 
    vmax=20, 
    skip_frames=4, 
    calibration_curve_paths=calibration_curve_paths, 
    show_scalebar=False,
    custom_title=None   
    )
# Out:
# Processing G-1 - Rep1: 100%|██████████| 533/533 [02:51<00:00,  3.11it/s]
# Processing G-2 - Rep1: 100%|██████████| 533/533 [03:47<00:00,  2.34it/s]
# Processing G-3 - Rep1: 100%|██████████| 533/533 [03:31<00:00,  2.52it/s]

# %%
# Example usage
qd.create_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    frame_rate=5,
    skip_frames=1
    )

# %%
qd.create_combined_heatmap_movie_custom_grid(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    grid_rows=1, 
    grid_cols=3, 
    frame_rate=60,
    batch_size=50
    )
# Out:
# Creating video with duration: 8.88 seconds.
# Creating combined frames: 100%|██████████| 533/533 [03:52<00:00,  2.29it/s]
# Combined video saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/output_data/movies/combined_heatmap_movie_cy5_60fps_533frames.avi

# %%
# Call the function
qd.fluorescence_heatmap(
    data_path, 
    conditions[:], 
    subconditions, 
    channel='GFP', 
    time_interval_list=time_interval_list, 
    vmax=200, 
    skip_frames=8, 
    calibration_curve_paths=calibration_curve_paths, 
    show_scalebar=False,
    )
# Out:
# Processing HeAl-1 - Rep1: 100%|██████████| 236/236 [00:50<00:00,  4.68it/s]
# Processing HeAl-2 - Rep1: 100%|██████████| 236/236 [00:53<00:00,  4.38it/s]
# Processing HeAl-3 - Rep1: 100%|██████████| 236/236 [00:49<00:00,  4.75it/s]

# %%
# Example usage
qd.create_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel='GFP', 
    frame_rate=15,
    skip_frames=1
    )

# %%
qd.create_combined_heatmap_movie_custom_grid(
    data_path, 
    conditions, 
    subconditions, 
    channel='GFP', 
    grid_rows=1, 
    grid_cols=3,       
    frame_rate=15,
    batch_size=50
    )
# Out:
# Creating video with duration: 15.73 seconds.
# Creating combined frames: 100%|██████████| 236/236 [01:19<00:00,  2.97it/s]
# Combined video saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031526-HeAl-3x/3ulTXTL-1ulMTs-0p5ulDNA_1/output_data/movies/combined_heatmap_movie_GFP_15fps_236frames.avi

# %%
# qd.delete_temporary_image_directories(data_path, conditions, subconditions)

# %% [markdown]
# ### Fluorescence Quantification

# %%
# Example usage
# mw_kda_list = [44.95] * len(conditions)
droplet_volume_list = [2] * len(conditions)
# protein_lengths_list = [401] * len(conditions) # last one is negative

qd.quantify_tiffiles(
    data_path, 
    conditions, 
    subconditions, 
    calibration_curve_paths, 
    droplet_volume_list, 
    time_interval_list, 
    skip_frames=1,
)
# Out:
# 2026-03-20 10:10:07,896 - INFO - Calibration concentrations (ug/ml) from filenames: [0.0, 2.0, 4.0, 9.0, 18.0, 35.0, 70.0, 140.0, 280.0]
# 2026-03-20 10:10:12,269 - INFO - ROI detected for G-1-Rep1: 1,863,543 px (eff. radius 770 px)
# 2026-03-20 10:10:13,768 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/output_data/roi_diagnostic_G-1_Rep1.png
# Calculating intensities for G-1 - Rep1: 100%|██████████| 2130/2130 [00:50<00:00, 42.45it/s]
# 2026-03-20 10:11:05,144 - INFO - ROI detected for G-2-Rep1: 1,856,495 px (eff. radius 769 px)
# 2026-03-20 10:11:06,288 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/output_data/roi_diagnostic_G-2_Rep1.png
# Calculating intensities for G-2 - Rep1: 100%|██████████| 2130/2130 [00:48<00:00, 43.95it/s]
# 2026-03-20 10:11:55,975 - INFO - ROI detected for G-3-Rep1: 1,148,881 px (eff. radius 605 px)
# 2026-03-20 10:11:57,102 - INFO - ROI diagnostic saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/output_data/roi_diagnostic_G-3_Rep1.png
# Calculating intensities for G-3 - Rep1: 100%|██████████| 2130/2130 [00:51<00:00, 41.25it/s]
# ('../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/output_data/combined_expression.csv',
#  '../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/output_data/mean_expression.csv')

# %% [markdown]
# ### PIV pre-processing

# %%
qd.split_tiffs(data_path, conditions, subconditions, channel='cy5', file_interval=1)
# Out:
# Copied every 1th f'cy5' file from ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/G-1/Rep1/original into ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/G-1/Rep1/cy5-1x.
# Copied every 1th f'cy5' file from ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/G-2/Rep1/original into ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/G-2/Rep1/cy5-1x.
# Copied every 1th f'cy5' file from ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/G-3/Rep1/original into ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/G-3/Rep1/cy5-1x.

# %% [markdown]
# ### PIV

# %%
# Define feature limits and other parameters
v = 2E-7
velocity_limits = (0, v)
other_limits = (-0.0005, 0.0005)
skip_frames = 1 ### CHANGE THIS TO SKIP FRAMES


velocity_limits = (None, None)
other_limits = (None, None)


feature_limits = {
    # 'u [m/s]': (-v, v), 
    # 'v [m/s]': (-v, v), 
    # 'data type [-]': (None, None),
    'velocity magnitude [m/s]': velocity_limits,
    'vorticity [1/s]': other_limits,
    'divergence [1/s]': other_limits,
    # 'dcev [1]': (0, 250),
    'shear [1/s]': other_limits,
    'strain [1/s]': other_limits,
    'vector direction [degrees]': (-180, 180),
}


# Features for PCA and plotting
features_pca = [
    "vorticity [1/s]_mean",
    "velocity magnitude [um/s]",
    "distance [m]_mean",
    "divergence [1/s]_mean",
    "shear [1/s]_mean",
    "strain [1/s]_mean",
    "correlation length [um]", 
    "power [W]_mean",
    "work [J]",
]

# %%
# time_interval_list = [60]  # time intervals in seconds between frames for each condition


# Process PIV data
qd.process_piv_data(
    data_path, 
    conditions,    
    subconditions, 
    feature_limits, 
    time_interval_list, 
    min_frame=0, 
    max_frame=None, 
    skip_frames=1, 
    plot_autocorrelation=False, 
    frame_rate=1, 
    heatmaps=False
    )
# Out:
# Processing PIV data:   0%|          | 0/3 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  33%|███▎      | 1/3 [00:07<00:14,  7.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  67%|██████▋   | 2/3 [00:14<00:07,  7.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data: 100%|██████████| 3/3 [00:22<00:00,  7.39s/it]

# %%
# Plot features and PCA
qd.plot_PIV_all(
    data_path, 
    conditions,
    subconditions, 
    features_pca, 
    min_frame=0, 
    max_frame=None
    )
# Out:
# Plotting PIV features: 100%|██████████| 3/3 [00:06<00:00,  2.07s/it]
# Plotting averaged PIV features: 100%|██████████| 3/3 [00:04<00:00,  1.52s/it]
# Collecting PIV data: 100%|██████████| 3/3 [00:00<00:00, 302.05it/s]

# %% [markdown]
# ### Expression + PIV

# %%
# Combine the data and save it to the "output_data" directory
qd.combine_averaged_dataframes(data_path, conditions, subconditions)
# Out:
# Conditions: 100%|██████████| 3/3 [00:00<00:00, 255.54it/s]
# Combined DataFrame saved to: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/output_data/combined_PIV.csv

# %%
qd.merge_expression_piv_data(data_path)
# Out:
# Merged DataFrame saved to: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/paperdata/031926-G/3ulTXTL-1ulMTs-0p5ulDNA_2/output_data/merged_expression_PIV.csv

# %%
# x_column = "time (h)"  # Example x-axis column
# y_column = "Protein Concentration_nM"  # Example y-axis column


# x_column = "Protein Concentration_nM"  # Example y-axis column
# y_column = "velocity magnitude [m/s]_mean"  # Example y-axis column

# x_column = "time (h)"  # Example x-axis column
# y_column = "velocity magnitude [m/s]_mean"  # Example y-axis column

# x_column = "time (h)"  # Example x-axis column
# y_column = "power [W]_mean"  # Example y-axis column

# x_column = "time (h)"  # Example x-axis column
# y_column = "work [J]_mean"  # Example y-axis column

x_column = "time (h)"  # Example x-axis column
y_column = "distance [m]_mean"  # Example y-axis column


qd.plot_expression_piv(
    data_path,
    conditions,
    x_column, 
    y_column, 
    sigma_x=0.1, 
    sigma_y=10, 
    x_log=False, 
    y_log=True, 
    min_frame=0, 
    max_frame=None, 
    individual_plots=False
    )

# %%
# List of features for PCA
features_pca = [
    "vorticity [1/s]_mean",
    "velocity magnitude [m/s]_mean",
    "distance [m]_mean",
    "divergence [1/s]_mean",
    "shear [1/s]_mean",
    "strain [1/s]_mean",
    "correlation length [m]_mean", 
    "power [W]_mean",
    "work [J]_mean",
    'vector direction [degrees]_mean',
    "Protein Concentration_nM", 
    'time (min)'
]

# Run PCA and save plot (with all conditions and subconditions in the same plot)
qd.plot_pca_expression_piv(data_path, conditions=conditions, subconditions=subconditions, features=features_pca, sigma=1)

# %%
# Example usage
qd.delete_outputs(data_path, conditions, subconditions, output_dirs=None)
