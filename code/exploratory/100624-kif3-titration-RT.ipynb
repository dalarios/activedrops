# %%
## Import relevant libraries
import sys
import glob

sys.path.append('../../py_files/')
import quadrop as qd

qd.set_plotting_style()

# %% [markdown]
# ### Data pre-procesing

# %%
# # Example usage
# base_dir = "../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/100624-kifr3-titration-RT/5ulTMB-2ulDNA160nM_2/"
# qd.consolidate_images(base_dir)

# %%
# Example usage
data_path = "../../../../Thomson Lab Dropbox/David Larios/activedrops/main/100624-kif3-titration-RT/2p5ulTMB-1ulDNAXnM_/"

calibration_curve_paths = sorted(glob.glob("../../../../Thomson Lab Dropbox/David Larios/activedrops/calibration-50ms/***ugml.tif"))


# conditions_dict = {
#     "Kif3_0p625nM_1-RT": "Pos0", 
#     "Kif3_0p625nM_2-RT": "Pos1",

# }

# # Organize PosX folders into condition folders
# qd.organize_conditions(data_path, conditions_dict)

# Now run the existing functions to reorganize the tiffs and rename the folders
conditions, subconditions = qd.prepare_conditions(data_path)
time_interval_list = [8] * len(conditions)  # time intervals in seconds between frames for each condition


print("Conditions:", conditions)
print("Subconditions:", subconditions)
# Out:
# Conditions: ['Kif3_0p625nM_2-RT', 'Kif3_1p25nM_1-RT', 'Kif3_1p25nM_2-RT', 'Kif3_2p5nM_1-RT', 'Kif3_2p5nM_2-RT', 'Kif3_5nM_1-RT', 'Kif3_5nM_2-RT', 'Kif3_10nM_1-RT', 'Kif3_10nM_2-RT', 'Kif3_20nM_1-RT', 'Kif3_20nM_2-RT', 'Kif3_40nM_1-RT', 'Kif3_40nM_2-RT', 'Kif3_80nM_1-RT', 'Kif3_80nM_2-RT', 'Kif3_160nM_1-RT', 'Kif3_160nM_2-RT', 'negative']
# Subconditions: ['Rep1']

# %%
# qd.reorgTiffsToOriginal(data_path, conditions, subconditions)
conditions[2:-1:2]
# Out:
# ['Kif3_1p25nM_2-RT',
#  'Kif3_2p5nM_2-RT',
#  'Kif3_5nM_2-RT',
#  'Kif3_10nM_2-RT',
#  'Kif3_20nM_2-RT',
#  'Kif3_40nM_2-RT',
#  'Kif3_80nM_2-RT',
#  'Kif3_160nM_2-RT']

# %% [markdown]
# ### Generate movies

# %%
conditions = conditions[1::2]
conditions
# Out:
# ['Kif3_1p25nM_1-RT',
#  'Kif3_2p5nM_1-RT',
#  'Kif3_5nM_1-RT',
#  'Kif3_10nM_1-RT',
#  'Kif3_20nM_1-RT',
#  'Kif3_40nM_1-RT',
#  'Kif3_80nM_1-RT',
#  'Kif3_160nM_1-RT',
#  'negative']

# %%
# Call the function
qd.fluorescence_heatmap(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    time_interval_list=time_interval_list, 
    vmax=2.5, 
    skip_frames=1, 
    calibration_curve_paths=calibration_curve_paths, 
    show_scalebar=False,
    )

# %%
# Example usage
qd.create_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    frame_rate=120,
    skip_frames=1
    )

# %%
qd.create_combined_heatmap_movie_custom_grid(
    data_path, 
    conditions[1::2], 
    subconditions, 
    channel='cy5', 
    grid_rows=2, 
    grid_cols=5, 
    frame_rate=120,
    batch_size=50
    )

# %%
# Call the function
qd.fluorescence_heatmap(
    data_path, 
    conditions, 
    subconditions, 
    channel='GFP', 
    time_interval_list=time_interval_list, 
    vmax=500, 
    skip_frames=1, 
    calibration_curve_paths=calibration_curve_paths, 
    show_scalebar=True,
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Call the function
# ----> 2 qd.fluorescence_heatmap(
#       3     data_path,
#       4     conditions,
#       5     subconditions,
#       6     channel='GFP',
#       7     time_interval_list=time_interval_list,
#       8     vmax=500,
#       9     skip_frames=1,
#      10     calibration_curve_paths=calibration_curve_paths,
#      11     show_scalebar=True,
#      12     )
#
# File ~/git/activedrops/code/exploratory/../../py_files/quadrop.py:447, in fluorescence_heatmap(data_path, conditions, subconditions, channel, time_interval_list, vmax, min_frame, max_frame, skip_frames, calibration_curve_paths, show_scalebar, batch_size)
#     444 sample_concentration_values = [initial_concentration/128, initial_concentration/64, initial_concentration/32, initial_concentration/16, initial_concentration/8, initial_concentration/4, initial_concentration/2, initial_concentration]
#     446 if calibration_curve_paths is None or len(calibration_curve_paths) != len(sample_concentration_values):
# --> 447     raise ValueError(f"Mismatch in lengths: {len(calibration_curve_paths)} calibration images, {len(sample_concentration_values)} sample concentrations")
#     449 mean_intensity_calibration = [calculate_mean_intensity(path) for path in calibration_curve_paths]
#     450 slope, intercept = np.polyfit(sample_concentration_values, mean_intensity_calibration, 1)
#
# ValueError: Mismatch in lengths: 9 calibration images, 8 sample concentrations

# %%
# Example usage
qd.create_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel='GFP', 
    frame_rate=120,
    skip_frames=1
    )
# Out:
# Creating video for Kif3_0p625nM_2-RT - Rep1 with duration: 15.00 seconds.
# Creating video for Kif3_0p625nM_2-RT - Rep1:   5%|▌         | 91/1800 [00:06<02:04, 13.73it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Example usage
# ----> 2 qd.create_movies(
#       3     data_path,
#       4     conditions,
#       5     subconditions,
#       6     channel='GFP',
#       7     frame_rate=120,
#       8     skip_frames=1
#       9     )
#
# File ~/git/activedrops/code/exploratory/../../py_files/quadrop.py:566, in create_movies(data_path, conditions, subconditions, channel, frame_rate, max_frame, skip_frames, batch_size)
#     564         for image_file in batch_files:
#     565             img = cv2.imread(image_file)
# --> 566             out.write(img)  # Write the image as a frame in the video
#     567             pbar.update(1)
#     569 # Release the video writer
#
# KeyboardInterrupt:

# %%
conditions[2:-1:2][::-1]
# Out:
# ['Kif3_160nM_2-RT',
#  'Kif3_80nM_2-RT',
#  'Kif3_40nM_2-RT',
#  'Kif3_20nM_2-RT',
#  'Kif3_10nM_2-RT',
#  'Kif3_5nM_2-RT',
#  'Kif3_2p5nM_2-RT',
#  'Kif3_1p25nM_2-RT']

# %%
qd.create_combined_heatmap_movie_custom_grid(
    data_path, 
    conditions[2:-1:2][::-1], 
    subconditions, 
    channel='GFP', 
    grid_rows=2, 
    grid_cols=4, 
    frame_rate=120,
    batch_size=50
    )
# Out:
# Creating video with duration: 15.00 seconds.
# Creating combined frames: 100%|██████████| 1800/1800 [10:53<00:00,  2.76it/s]
# Combined video saved to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/100624-kif3-titration-RT/2p5ulTMB-1ulDNAXnM_/output_data/movies/combined_heatmap_movie_GFP_120fps_1800frames.avi

# %%
# qd.delete_temporary_image_directories(data_path, conditions, subconditions)

# %% [markdown]
# ### Fluorescence Quantification

# %%
# Example usage
mw_kda_list = [64.4] * len(conditions)
droplet_volume_list = [2] * len(conditions)
protein_lengths_list = [592] * len(conditions)

qd.quantify_tiffiles(
    data_path, 
    conditions, 
    subconditions, 
    calibration_curve_paths, 
    mw_kda_list, 
    droplet_volume_list, 
    time_interval_list, 
    protein_lengths_list,
    ribosome_count=10**9,
    skip_frames=1,
    subtract_negative=True
)
# Out:
# Calculating sample intensities: 100%|██████████| 1800/1800 [00:02<00:00, 699.84it/s]
# Calculating sample intensities: 100%|██████████| 1800/1800 [00:02<00:00, 765.06it/s]
# Calculating sample intensities: 100%|██████████| 1800/1800 [00:02<00:00, 774.24it/s]
# Calculating sample intensities: 100%|██████████| 1800/1800 [00:02<00:00, 772.54it/s]
# Calculating sample intensities: 100%|██████████| 1800/1800 [00:02<00:00, 757.28it/s]
# Calculating sample intensities: 100%|██████████| 1800/1800 [00:02<00:00, 769.08it/s]
# Calculating sample intensities: 100%|██████████| 1800/1800 [00:02<00:00, 755.53it/s]
# Calculating sample intensities: 100%|██████████| 1800/1800 [00:02<00:00, 751.28it/s]
# Calculating sample intensities: 100%|██████████| 1800/1800 [00:02<00:00, 793.69it/s]
# ('../../../../Thomson Lab Dropbox/David Larios/activedrops/main/100624-kif3-titration-RT/2p5ulTMB-1ulDNAXnM_/output_data/combined_expression.csv',
#  '../../../../Thomson Lab Dropbox/David Larios/activedrops/main/100624-kif3-titration-RT/2p5ulTMB-1ulDNAXnM_/output_data/mean_expression.csv')

# %% [markdown]
# ### PIV pre-processing

# %%
conditions
# Out:
# ['Kif3_1p25nM_1-RT',
#  'Kif3_2p5nM_1-RT',
#  'Kif3_5nM_1-RT',
#  'Kif3_10nM_1-RT',
#  'Kif3_20nM_1-RT',
#  'Kif3_40nM_1-RT',
#  'Kif3_80nM_1-RT',
#  'Kif3_160nM_1-RT',
#  'negative']

# %%
qd.split_tiffs(data_path, conditions, subconditions, channel='gfp', file_interval=1)

# %% [markdown]
# ### PIV

# %%
# Define feature limits and other parameters
v = 2E-7
velocity_limits = (0, v)
other_limits = (-0.0005, 0.0005)
skip_frames = 1 ### CHANGE THIS TO SKIP FRAMES


velocity_limits = (None, None)
other_limits = (None, None)


feature_limits = {
    # 'u [m/s]': (-v, v), 
    # 'v [m/s]': (-v, v), 
    # 'data type [-]': (None, None),
    'velocity magnitude [m/s]': velocity_limits,
    'vorticity [1/s]': other_limits,
    'divergence [1/s]': other_limits,
    # 'dcev [1]': (0, 250),
    'shear [1/s]': other_limits,
    'strain [1/s]': other_limits,
    'vector direction [degrees]': (-180, 180),
}


# Features for PCA and plotting
features_pca = [
    "vorticity [1/s]_mean",
    "velocity magnitude [um/s]",
    "distance [m]_mean",
    "divergence [1/s]_mean",
    "shear [1/s]_mean",
    "strain [1/s]_mean",
    "correlation length [um]", 
    "power [W]_mean",
    "work [J]",
]

# %%
conditions = conditions[::-1]
conditions

# %%
time_interval_list = [8] * len(conditions)  # time intervals in seconds between frames for each condition


# Process PIV data
qd.process_piv_data(
    data_path, 
    conditions,
    subconditions, 
    feature_limits, 
    time_interval_list, 
    min_frame=0, 
    max_frame=None, 
    skip_frames=1, 
    plot_autocorrelation=False, 
    frame_rate=1, 
    heatmaps=False
    )
# Out:
# Processing PIV data:   0%|          | 0/8 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  12%|█▎        | 1/8 [00:15<01:50, 15.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  25%|██▌       | 2/8 [00:32<01:38, 16.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  38%|███▊      | 3/8 [00:49<01:21, 16.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  50%|█████     | 4/8 [01:05<01:05, 16.41s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  62%|██████▎   | 5/8 [01:22<00:49, 16.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  75%|███████▌  | 6/8 [01:39<00:33, 16.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  88%|████████▊ | 7/8 [01:56<00:16, 16.97s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data: 100%|██████████| 8/8 [02:14<00:00, 16.80s/it]

# %%
conditions[:-1]
# Out:
# ['Kif3_1p25nM_1-RT',
#  'Kif3_2p5nM_1-RT',
#  'Kif3_5nM_1-RT',
#  'Kif3_10nM_1-RT',
#  'Kif3_20nM_1-RT',
#  'Kif3_40nM_1-RT',
#  'Kif3_80nM_1-RT',
#  'Kif3_160nM_1-RT']

# %%
# Plot features and PCA
qd.plot_PIV_all(
    data_path, 
    conditions[:-1],
    subconditions, 
    features_pca, 
    min_frame=0, 
    max_frame=None
    )
# Out:
# Plotting PIV features: 100%|██████████| 8/8 [00:15<00:00,  1.99s/it]
# Plotting averaged PIV features: 100%|██████████| 8/8 [00:11<00:00,  1.48s/it]
# Collecting PIV data: 100%|██████████| 8/8 [00:00<00:00, 203.73it/s]

# %% [markdown]
# ### Expression + PIV

# %%
# Combine the data and save it to the "output_data" directory
qd.combine_averaged_dataframes(data_path, conditions, subconditions)
# Out:
# Conditions: 100%|██████████| 9/9 [00:00<00:00, 107.96it/s]
# 'Averaged' folder not found for negative/Rep1. Skipping...
# Combined DataFrame saved to: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/100624-kif3-titration-RT/2p5ulTMB-1ulDNAXnM_/output_data/combined_PIV.csv

# %%
qd.merge_expression_piv_data(data_path)

# %%
# x_column = "time (h)"  # Example x-axis column
# y_column = "Protein Concentration_nM"  # Example y-axis column


# x_column = "Protein Concentration_nM"  # Example y-axis column
# y_column = "velocity magnitude [m/s]_mean"  # Example y-axis column

# x_column = "time (h)"  # Example x-axis column
# y_column = "velocity magnitude [m/s]_mean"  # Example y-axis column

# x_column = "time (h)"  # Example x-axis column
# y_column = "power [W]_mean"  # Example y-axis column

# x_column = "time (h)"  # Example x-axis column
# y_column = "work [J]_mean"  # Example y-axis column

x_column = "time (h)"  # Example x-axis column
y_column = "distance [m]_mean"  # Example y-axis column


qd.plot_expression_piv(
    data_path,
    conditions,
    x_column, 
    y_column, 
    sigma_x=0.1, 
    sigma_y=10, 
    x_log=False, 
    y_log=True, 
    min_frame=0, 
    max_frame=None, 
    individual_plots=False
    )

# %%
# List of features for PCA
features_pca = [
    "vorticity [1/s]_mean",
    "velocity magnitude [m/s]_mean",
    "distance [m]_mean",
    "divergence [1/s]_mean",
    "shear [1/s]_mean",
    "strain [1/s]_mean",
    "correlation length [m]_mean", 
    "power [W]_mean",
    "work [J]_mean",
    'vector direction [degrees]_mean',
    "Protein Concentration_nM", 
    'time (min)'
]

# Run PCA and save plot (with all conditions and subconditions in the same plot)
qd.plot_pca_expression_piv(data_path, conditions=conditions, subconditions=subconditions, features=features_pca, sigma=1)

# %%
# Example usage
qd.delete_outputs(data_path, conditions, subconditions, output_dirs=None)
