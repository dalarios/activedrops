# %%
## Import relevant libraries
import sys
import os
import shutil
from natsort import natsorted  # For natural sorting
sys.path.append('../../activedrops')

## Including ourselves
import quadrop as qd
qd.set_plotting_style()

# %%
data_path = "../../data/kif3_g6p_titration/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])

# %%
def reorgTiffsToOriginal(data_path, conditions, subconditions):
    """
    Args:
        data_path (_type_): _description_
        conditions (_type_): _description_
        subconditions (_type_): _description_
        
        
    Activate when you have your subconditions inside the conditions folder. 
    This function renames the subconditions as PosX and moves the raw data do "original" folder.
    """
    
    
    for condition in conditions:
        # Get the actual subconditions in the directory
        actual_subconditions = [name for name in os.listdir(os.path.join(data_path, condition)) if os.path.isdir(os.path.join(data_path, condition, name))]
        
        # Rename the actual subconditions to match the subconditions in your list
        for i, actual_subcondition in enumerate(sorted(actual_subconditions)):
            os.rename(os.path.join(data_path, condition, actual_subcondition), os.path.join(data_path, condition, subconditions[i]))
        
        for subcondition in subconditions:
            # Construct the path to the subcondition directory
            subcondition_path = os.path.join(data_path, condition, subcondition)
            
            # Create the path for the "original" directory within the subcondition directory
            original_dir_path = os.path.join(subcondition_path, "original")
            
            # Always create the "original" directory
            os.makedirs(original_dir_path, exist_ok=True)
            
            # Iterate over all files in the subcondition directory
            for filename in os.listdir(subcondition_path):
                # Check if the file is a .tif file
                if filename.endswith(".tif"):
                    # Construct the full path to the file
                    file_path = os.path.join(subcondition_path, filename)
                    
                    # Construct the path to move the file to
                    destination_path = os.path.join(original_dir_path, filename)
                    
                    # Move the file to the "original" directory
                    shutil.move(file_path, destination_path)
            print(f"Moved .tif files from {subcondition_path} to {original_dir_path}")


reorgTiffsToOriginal(data_path, conditions, subconditions)
# Out:
# Moved .tif files from ../../data/kif3_g6p_titration/20MT-0mM_G6P/Pos0 to ../../data/kif3_g6p_titration/20MT-0mM_G6P/Pos0/original
# Moved .tif files from ../../data/kif3_g6p_titration/20MT-0mM_G6P/Pos1 to ../../data/kif3_g6p_titration/20MT-0mM_G6P/Pos1/original
# Moved .tif files from ../../data/kif3_g6p_titration/20MT-0mM_G6P/Pos2 to ../../data/kif3_g6p_titration/20MT-0mM_G6P/Pos2/original
# Moved .tif files from ../../data/kif3_g6p_titration/20MT-5mM_G6P/Pos0 to ../../data/kif3_g6p_titration/20MT-5mM_G6P/Pos0/original
# Moved .tif files from ../../data/kif3_g6p_titration/20MT-5mM_G6P/Pos1 to ../../data/kif3_g6p_titration/20MT-5mM_G6P/Pos1/original
# Moved .tif files from ../../data/kif3_g6p_titration/20MT-5mM_G6P/Pos2 to ../../data/kif3_g6p_titration/20MT-5mM_G6P/Pos2/original
# Moved .tif files from ../../data/kif3_g6p_titration/20MT-10mM_G6P/Pos0 to ../../data/kif3_g6p_titration/20MT-10mM_G6P/Pos0/original
# Moved .tif files from ../../data/kif3_g6p_titration/20MT-10mM_G6P/Pos1 to ../../data/kif3_g6p_titration/20MT-10mM_G6P/Pos1/original
# Moved .tif files from ../../data/kif3_g6p_titration/20MT-10mM_G6P/Pos2 to ../../data/kif3_g6p_titration/20MT-10mM_G6P/Pos2/original
# Moved .tif files from ../../data/kif3_g6p_titration/grid_heatmaps_cy5/Pos0 to ../../data/kif3_g6p_titration/grid_heatmaps_cy5/Pos0/original
# Moved .tif files from ../../data/kif3_g6p_titration/grid_heatmaps_cy5/Pos1 to ../../data/kif3_g6p_titration/grid_heatmaps_cy5/Pos1/original
# Moved .tif files from ../../data/kif3_g6p_titration/grid_heatmaps_cy5/Pos2 to ../../data/kif3_g6p_titration/grid_heatmaps_cy5/Pos2/original
# Moved .tif files from ../../data/kif3_g6p_titration/grid_heatmaps_gfp/Pos0 to ../../data/kif3_g6p_titration/grid_heatmaps_gfp/Pos0/original
# Moved .tif files from ../../data/kif3_g6p_titration/grid_heatmaps_gfp/Pos1 to ../../data/kif3_g6p_titration/grid_heatmaps_gfp/Pos1/original
# Moved .tif files from ../../data/kif3_g6p_titration/grid_heatmaps_gfp/Pos2 to ../../data/kif3_g6p_titration/grid_heatmaps_gfp/Pos2/original
# Moved .tif files from ../../data/kif3_g6p_titration/noMT-0mM_G6P/Pos0 to ../../data/kif3_g6p_titration/noMT-0mM_G6P/Pos0/original
# Moved .tif files from ../../data/kif3_g6p_titration/noMT-0mM_G6P/Pos1 to ../../data/kif3_g6p_titration/noMT-0mM_G6P/Pos1/original
# Moved .tif files from ../../data/kif3_g6p_titration/noMT-0mM_G6P/Pos2 to ../../data/kif3_g6p_titration/noMT-0mM_G6P/Pos2/original
# Moved .tif files from ../../data/kif3_g6p_titration/noMT-5mM_G6P/Pos0 to ../../data/kif3_g6p_titration/noMT-5mM_G6P/Pos0/original
# Moved .tif files from ../../data/kif3_g6p_titration/noMT-5mM_G6P/Pos1 to ../../data/kif3_g6p_titration/noMT-5mM_G6P/Pos1/original
# Moved .tif files from ../../data/kif3_g6p_titration/noMT-5mM_G6P/Pos2 to ../../data/kif3_g6p_titration/noMT-5mM_G6P/Pos2/original
# Moved .tif files from ../../data/kif3_g6p_titration/noMT-10mM_G6P/Pos0 to ../../data/kif3_g6p_titration/noMT-10mM_G6P/Pos0/original
# Moved .tif files from ../../data/kif3_g6p_titration/noMT-10mM_G6P/Pos1 to ../../data/kif3_g6p_titration/noMT-10mM_G6P/Pos1/original
# Moved .tif files from ../../data/kif3_g6p_titration/noMT-10mM_G6P/Pos2 to ../../data/kif3_g6p_titration/noMT-10mM_G6P/Pos2/original
# Moved .tif files from ../../data/kif3_g6p_titration/single_movies_cy5/Pos0 to ../../data/kif3_g6p_titration/single_movies_cy5/Pos0/original
# Moved .tif files from ../../data/kif3_g6p_titration/single_movies_cy5/Pos1 to ../../data/kif3_g6p_titration/single_movies_cy5/Pos1/original
# Moved .tif files from ../../data/kif3_g6p_titration/single_movies_cy5/Pos2 to ../../data/kif3_g6p_titration/single_movies_cy5/Pos2/original
# Moved .tif files from ../../data/kif3_g6p_titration/single_movies_gfp/Pos0 to ../../data/kif3_g6p_titration/single_movies_gfp/Pos0/original
# Moved .tif files from ../../data/kif3_g6p_titration/single_movies_gfp/Pos1 to ../../data/kif3_g6p_titration/single_movies_gfp/Pos1/original
# Moved .tif files from ../../data/kif3_g6p_titration/single_movies_gfp/Pos2 to ../../data/kif3_g6p_titration/single_movies_gfp/Pos2/original

# %%
# frame info
min_frame = 0
max_frame = 250
skip_frames=16
frame_rate=30
time_intervals = [30] * len(conditions)

# %%
# Call the function with the updated parameters
qd.plot_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="gfp",
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False,  # Set log_scale to True
    timescale="min"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Call the function with the updated parameters
# ----> 2 qd.plot_fluorescence_vs_time(
#       3     data_path=data_path,
#       4     conditions=conditions,
#       5     subconditions=subconditions,
#       6     channel="gfp",
#       7     time_intervals=time_intervals,
#       8     min_frame=min_frame,
#       9     max_frame=max_frame,
#      10     skip_frames=skip_frames,
#      11     log_scale=False,  # Set log_scale to True
#      12     timescale="min"
#      13 )
#
# File ~/git/activedrops/code/exploratory/../../activedrops/quadrop.py:209, in plot_fluorescence_vs_time(data_path, conditions, subconditions, channel, time_intervals, min_frame, max_frame, skip_frames, log_scale, timescale)
#     204     frames.append(i * skip_frames)
#     205     intensities.append(mean_intensity)
#     207 results_df = pd.DataFrame({
#     208     "frame": frames,
# --> 209     "mean_intensity": intensities - np.min(intensities)
#     210 })
#     212 smoothed_intensities = gaussian_filter1d(results_df["mean_intensity"], sigma=1)
#     214 alpha = 0.3 + (sub_idx / len(subconditions)) * 0.7
#
# File <__array_function__ internals>:200, in amin(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2946, in amin(a, axis, out, keepdims, initial, where)
#    2829 @array_function_dispatch(_amin_dispatcher)
#    2830 def amin(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2831          where=np._NoValue):
#    2832     """
#    2833     Return the minimum of an array or minimum along an axis.
#    2834
#    (...)
#    2944     6
#    2945     """
# -> 2946     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2947                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
subconditions[:3]

# %%
# Call the function with the updated parameters
qd.plot_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions[:3],
    subconditions=subconditions,
    channel="gfp",
    time_intervals=time_intervals[:3],  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False,  # Set log_scale to True
    timescale="min"
)

# %%
# Call the function with the updated parameters
qd.plot_average_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions[:3],
    subconditions=subconditions,
    channel="gfp",
    time_intervals=time_intervals[:3],  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False,  # Set log_scale to True
    timescale="min"
)

# %%
# Call the function with the updated parameters
qd.plot_average_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions[:3],
    subconditions=subconditions,
    channel="gfp",
    time_intervals=time_intervals[:3],  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False,  # Set log_scale to True
    timescale="min"
)

# %%
conditions_MT = conditions[:3]
conditions_MT

# %%
# Example usage
conditions_MT = conditions[:3]

# frame info
min_frame = 0
max_frame = None
skip_frames=1
frame_rate=30
time_intervals = [30, 30, 30]

# channel info
channel = "cy5"
vmax = 0.4

qd.single_fluorescence_movies(data_path, conditions_MT, subconditions, channel, time_intervals, min_frame, max_frame, vmax, skip_frames, frame_rate)

# %%
qd.grid_heatmaps(data_path, conditions_MT, subconditions, channel, frame_rate=frame_rate, figsize=(20,24))

# %%
# channel info
channel = "gfp"
vmax = 0.02

qd.single_fluorescence_movies(data_path, conditions_MT, subconditions, channel, time_intervals, min_frame, max_frame, vmax, skip_frames, frame_rate)

# %%
qd.grid_heatmaps(data_path, conditions_MT, subconditions, channel, frame_rate=frame_rate, figsize=(20,24))

# %%
# frame info
min_frame = 0
max_frame = None
skip_frames=4
frame_rate=30
time_intervals = [30, 30, 30]

# channel info
channel = "gfp"
vmax = 0.02

qd.single_fluorescence_movies(data_path, conditions[3:], subconditions, channel, time_intervals, min_frame, max_frame, vmax, skip_frames, frame_rate)

# %%
qd.grid_heatmaps(data_path, conditions[3:], subconditions, channel, frame_rate=frame_rate, figsize=(20,24))
