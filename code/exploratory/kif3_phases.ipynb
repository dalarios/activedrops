# %%
## Import relevant libraries
import sys
sys.path.append('../../activedrops')
import pivdrops
import viz
pivdrops.set_plotting_style()

# %%
# Example usage
data_path = "../../data/kif3_phases"
conditions = ["10MT", "20MT", "40MT"]
subconditions = ["40DNA", "60DNA", "80DNA"]
min_frame = 0
max_frame = None



# Call the function with the updated parameters
df_cy5 = viz.plot_mean_fluorescence_over_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="cy5",
    time_interval=30,  
    min_frame=min_frame,
    max_frame=None,
    skip_frames=16,
    log_scale=True  # Set log_scale to True
)

# %%
# Example usage
data_path = "../../data/kif3_phases"
conditions = ["10MT", "20MT", "40MT"]
subconditions = ["40DNA", "60DNA", "80DNA"]
min_frame = 0
max_frame = None



# Call the function with the updated parameters
df_cy5 = viz.plot_mean_fluorescence_over_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="gfp",
    time_interval=30,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=16,
    log_scale=True  # Set log_scale to True
)

# %%
viz.process_all_conditions_and_subconditions(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="gfp",
    time_interval=30,  # Adjust as needed
    skip_frames=16,
    vmax=1400,  # Adjust as needed
    frame_rate=120,  # Adjust as needed
    min_frame=1,
    max_frame=None,
)
# Out:
# Video saved to ../../data/kif3_phases\10MT\40DNA\10MT_40DNA-gfp.avi
# Video saved to ../../data/kif3_phases\10MT\60DNA\10MT_60DNA-gfp.avi
# Video saved to ../../data/kif3_phases\10MT\80DNA\10MT_80DNA-gfp.avi
# Video saved to ../../data/kif3_phases\20MT\40DNA\20MT_40DNA-gfp.avi
# Video saved to ../../data/kif3_phases\20MT\60DNA\20MT_60DNA-gfp.avi
# Video saved to ../../data/kif3_phases\20MT\80DNA\20MT_80DNA-gfp.avi
# Video saved to ../../data/kif3_phases\40MT\40DNA\40MT_40DNA-gfp.avi
# Video saved to ../../data/kif3_phases\40MT\60DNA\40MT_60DNA-gfp.avi
# Video saved to ../../data/kif3_phases\40MT\80DNA\40MT_80DNA-gfp.avi
