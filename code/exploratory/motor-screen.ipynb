# %%
## Import relevant libraries
import sys
import os
import shutil
from natsort import natsorted  # For natural sorting
sys.path.append('../../activedrops')

## Including ourselves
import quadrop as qd
qd.set_plotting_style()

# %%
data_path = "../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])

subconditions
# Out:
# ['Pos0']

# %%
def reorgTiffsToOriginal(data_path, conditions, subconditions):
    """
    Args:
        data_path (_type_): _description_
        conditions (_type_): _description_
        subconditions (_type_): _description_
        
        
    Activate when you have your subconditions inside the conditions folder. 
    This function renames the subconditions as PosX and moves the raw data do "original" folder.
    """
    
    
    for condition in conditions:
        # Get the actual subconditions in the directory
        actual_subconditions = [name for name in os.listdir(os.path.join(data_path, condition)) if os.path.isdir(os.path.join(data_path, condition, name))]
        
        # Rename the actual subconditions to match the subconditions in your list
        for i, actual_subcondition in enumerate(sorted(actual_subconditions)):
            os.rename(os.path.join(data_path, condition, actual_subcondition), os.path.join(data_path, condition, subconditions[i]))
        
        for subcondition in subconditions:
            # Construct the path to the subcondition directory
            subcondition_path = os.path.join(data_path, condition, subcondition)
            
            # Create the path for the "original" directory within the subcondition directory
            original_dir_path = os.path.join(subcondition_path, "original")
            
            # Always create the "original" directory
            os.makedirs(original_dir_path, exist_ok=True)
            
            # Iterate over all files in the subcondition directory
            for filename in os.listdir(subcondition_path):
                # Check if the file is a .tif file
                if filename.endswith(".tif"):
                    # Construct the full path to the file
                    file_path = os.path.join(subcondition_path, filename)
                    
                    # Construct the path to move the file to
                    destination_path = os.path.join(original_dir_path, filename)
                    
                    # Move the file to the "original" directory
                    shutil.move(file_path, destination_path)
            print(f"Moved .tif files from {subcondition_path} to {original_dir_path}")


reorgTiffsToOriginal(data_path, conditions, subconditions)
# Out:
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/AcSu\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/AcSu\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/AcSu2\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/AcSu2\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/AdPa\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/AdPa\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/BleSto2\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/BleSto2\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/CaFa\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/CaFa\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/DiDi\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/DiDi\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/DiPu\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/DiPu\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/Giin\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/Giin\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/HeAl\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/HeAl\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/NCD\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/NCD\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/NaFo\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/NaFo\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/NaGr\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/NaGr\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/PaBi\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/PaBi\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/PoVi\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/PoVi\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/SteCoe\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/SteCoe\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/SteCoe4\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/SteCoe4\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/StyLe\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/StyLe\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/ThTr\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/ThTr\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/TiLa\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/TiLa\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/TrBr\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/TrBr\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/TrVa\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/TrVa\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/Unc\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/Unc\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/kif5\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/kif5\Pos0\original
# Moved .tif files from ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/kva\Pos0 to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/kva\Pos0\original

# %%
# frame info
min_frame = 0
max_frame = None
skip_frames=8
frame_rate=30
time_intervals = [300] * len(conditions)

# %%
# Call the function with the updated parameters
qd.plot_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="gfp",
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False,  # Set log_scale to True
    timescale="min"
)

# %%
# frame info
min_frame = 0
max_frame = None
skip_frames=1
frame_rate=30
time_intervals = [300] * len(conditions)

# channel info
channel = "cy5"
vmax = 0.2

qd.single_fluorescence_movies(data_path, conditions, subconditions, channel, time_intervals, min_frame, max_frame, vmax, skip_frames, frame_rate)
# Out:
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\AcSu_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\AcSu2_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\AdPa_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\BleSto2_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\CaFa_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\DiDi_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\DiPu_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\Giin_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\HeAl_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\NCD_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\NaFo_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\NaGr_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\PaBi_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\PoVi_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\SteCoe_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\SteCoe4_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\StyLe_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\ThTr_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\TiLa_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\TrBr_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\TrVa_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\Unc_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\kif5_Pos0-cy5.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_cy5\kva_Pos0-cy5.avi

# %%
# qd.grid_heatmaps(data_path, conditions, subconditions, channel, frame_rate=frame_rate, figsize=(20,24))

# %%
# channel info
channel = "gfp"
vmax = 0.02

qd.single_fluorescence_movies(data_path, conditions, subconditions, channel, time_intervals, min_frame, max_frame, vmax, skip_frames, frame_rate)
# Out:
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_gfp\AcSu_Pos0-gfp.avi
# Video saved to ../../data/motors-screening/4ulTXTL-0p5ulMT-0p6DNA40nM-1p5PBS5p4/single_movies_gfp\AcSu2_Pos0-gfp.avi
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[24], line 5
#       2 channel = "gfp"
#       3 vmax = 0.02
# ----> 5 qd.single_fluorescence_movies(data_path, conditions, subconditions, channel, time_intervals, min_frame, max_frame, vmax, skip_frames, frame_rate)
#
# File c:\Users\Admin\git\activedrops\code\exploratory\../../activedrops\quadrop.py:450, in single_fluorescence_movies(data_path, conditions, subconditions, channel, time_intervals, min_frame, max_frame, vmax, skip_frames, frame_rate)
#     447 time_interval = time_intervals[i]
#     448 for subcondition in subconditions:
#     449     # Create heatmaps for each condition and subcondition
# --> 450     fluorescence_heatmap(
#     451         data_path=data_path,
#     452         condition=condition,
#     453         subcondition=subcondition,
#     454         channel=channel,
#     455         time_interval=time_interval,
#     456         min_frame=min_frame,
#     457         max_frame=max_frame,
#     458         vmax=vmax,
#     459         skip_frames=skip_frames
#     460     )
#     462     # Create annotated image movies for each condition and subcondition
#     463     create_movies(
#     464         data_path=data_path,
#     465         condition=condition,
#    (...)
#     470         max_frame=max_frame
#     471     )
#
# File c:\Users\Admin\git\activedrops\code\exploratory\../../activedrops\quadrop.py:365, in fluorescence_heatmap(data_path, condition, subcondition, channel, time_interval, min_frame, max_frame, vmax, skip_frames)
#     363 heatmap_filename = f"heatmap_frame_{i}.tif"
#     364 heatmap_path = os.path.join(output_directory_path, heatmap_filename)
# --> 365 plt.savefig(heatmap_path, bbox_inches='tight', pad_inches=0.1, dpi=300)
#     366 plt.close(fig)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:1134, in savefig(*args, **kwargs)
#    1131 fig = gcf()
#    1132 # savefig default implementation has no return, so mypy is unhappy
#    1133 # presumably this is here because subclasses can return?
# -> 1134 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1135 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1136 return res
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backend_bases.py:2164, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2161     # we do this instead of `self.figure.draw_without_rendering`
#    2162     # so that we can inject the orientation
#    2163     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2164         self.figure.draw(renderer)
#    2165 if bbox_inches:
#    2166     if bbox_inches == "tight":
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:649, in _ImageBase.draw(self, renderer, *args, **kwargs)
#     647         renderer.draw_image(gc, l, b, im, trans)
#     648 else:
# --> 649     im, l, b, trans = self.make_image(
#     650         renderer, renderer.get_image_magnification())
#     651     if im is not None:
#     652         renderer.draw_image(gc, l, b, im)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:939, in AxesImage.make_image(self, renderer, magnification, unsampled)
#     936 transformed_bbox = TransformedBbox(bbox, trans)
#     937 clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     938         else self.figure.bbox)
# --> 939 return self._make_image(self._A, bbox, transformed_bbox, clip,
#     940                         magnification, unsampled=unsampled)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:454, in _ImageBase._make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     445     scaled_dtype = np.float64 if da > 1e8 else np.float32
#     447 # Scale the input data to [.1, .9].  The Agg interpolators clip
#     448 # to [0, 1] internally, and we use a smaller input scale to
#     449 # identify the interpolated points that need to be flagged as
#    (...)
#     452
#     453 # Always copy, and don't allow array subtypes.
# --> 454 A_scaled = np.array(A, dtype=scaled_dtype)
#     455 # Clip scaled data around norm if necessary.  This is necessary
#     456 # for big numbers at the edge of float64's ability to represent
#     457 # changes.  Applying a norm first would be good, but ruins the
#     458 # interpolation of over numbers.
#     459 self.norm.autoscale_None(A)
#
# MemoryError: Unable to allocate 32.0 MiB for an array with shape (2048, 2048) and data type float64
# Error in callback <function _draw_all_if_interactive at 0x0000027571797380> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backends\backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:649, in _ImageBase.draw(self, renderer, *args, **kwargs)
#     647         renderer.draw_image(gc, l, b, im, trans)
#     648 else:
# --> 649     im, l, b, trans = self.make_image(
#     650         renderer, renderer.get_image_magnification())
#     651     if im is not None:
#     652         renderer.draw_image(gc, l, b, im)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:939, in AxesImage.make_image(self, renderer, magnification, unsampled)
#     936 transformed_bbox = TransformedBbox(bbox, trans)
#     937 clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     938         else self.figure.bbox)
# --> 939 return self._make_image(self._A, bbox, transformed_bbox, clip,
#     940                         magnification, unsampled=unsampled)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:454, in _ImageBase._make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     445     scaled_dtype = np.float64 if da > 1e8 else np.float32
#     447 # Scale the input data to [.1, .9].  The Agg interpolators clip
#     448 # to [0, 1] internally, and we use a smaller input scale to
#     449 # identify the interpolated points that need to be flagged as
#    (...)
#     452
#     453 # Always copy, and don't allow array subtypes.
# --> 454 A_scaled = np.array(A, dtype=scaled_dtype)
#     455 # Clip scaled data around norm if necessary.  This is necessary
#     456 # for big numbers at the edge of float64's ability to represent
#     457 # changes.  Applying a norm first would be good, but ruins the
#     458 # interpolation of over numbers.
#     459 self.norm.autoscale_None(A)
#
# MemoryError: Unable to allocate 32.0 MiB for an array with shape (2048, 2048) and data type float64
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backend_bases.py:2164, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2161     # we do this instead of `self.figure.draw_without_rendering`
#    2162     # so that we can inject the orientation
#    2163     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2164         self.figure.draw(renderer)
#    2165 if bbox_inches:
#    2166     if bbox_inches == "tight":
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:649, in _ImageBase.draw(self, renderer, *args, **kwargs)
#     647         renderer.draw_image(gc, l, b, im, trans)
#     648 else:
# --> 649     im, l, b, trans = self.make_image(
#     650         renderer, renderer.get_image_magnification())
#     651     if im is not None:
#     652         renderer.draw_image(gc, l, b, im)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:939, in AxesImage.make_image(self, renderer, magnification, unsampled)
#     936 transformed_bbox = TransformedBbox(bbox, trans)
#     937 clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     938         else self.figure.bbox)
# --> 939 return self._make_image(self._A, bbox, transformed_bbox, clip,
#     940                         magnification, unsampled=unsampled)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:454, in _ImageBase._make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     445     scaled_dtype = np.float64 if da > 1e8 else np.float32
#     447 # Scale the input data to [.1, .9].  The Agg interpolators clip
#     448 # to [0, 1] internally, and we use a smaller input scale to
#     449 # identify the interpolated points that need to be flagged as
#    (...)
#     452
#     453 # Always copy, and don't allow array subtypes.
# --> 454 A_scaled = np.array(A, dtype=scaled_dtype)
#     455 # Clip scaled data around norm if necessary.  This is necessary
#     456 # for big numbers at the edge of float64's ability to represent
#     457 # changes.  Applying a norm first would be good, but ruins the
#     458 # interpolation of over numbers.
#     459 self.norm.autoscale_None(A)
#
# MemoryError: Unable to allocate 32.0 MiB for an array with shape (2048, 2048) and data type float64

# %%
qd.grid_heatmaps(data_path, conditions_MT, subconditions, channel, frame_rate=frame_rate, figsize=(20,24))

# %%
# frame info
min_frame = 0
max_frame = None
skip_frames=4
frame_rate=30
time_intervals = [30, 30, 30]

# channel info
channel = "gfp"
vmax = 0.02

qd.single_fluorescence_movies(data_path, conditions[3:], subconditions, channel, time_intervals, min_frame, max_frame, vmax, skip_frames, frame_rate)

# %%
qd.grid_heatmaps(data_path, conditions[3:], subconditions, channel, frame_rate=frame_rate, figsize=(20,24))
