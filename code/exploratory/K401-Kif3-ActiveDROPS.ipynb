# %%
import sys
sys.path.append('../../activedrops')

import os
import pandas as pd
import viz
import pivdrops

viz.set_plotting_style()

# %% [markdown]
# The first thing will be to load our movies: K401-mVenus-Avitag, Kif3-mVenus-Avitag, K401-biotin-streptavidin (protein standard).

# %%
raw_piv_data = "C:/Users/dalar/OneDrive/Desktop/current_experiment/100223-kbio-500_250_125nM/pos1-250nM/piv-pos1-250nM/txt-250nM-complete_movie/PIVlab_****.txt"
processed_data = "C:/Users/dalar/OneDrive/Desktop/current_experiment/100223-kbio-500_250_125nM/pos1-250nM/piv-pos1-250nM/250nM_L250.csv"

# pivdrops.process_piv_data(raw_piv_data, time_int=3, µl=2, L=250, vmax=True, remove_end_frames=1238, save_path=processed_data)

# %%
df250 = pd.read_csv(processed_data)

# %%
# df250['time_min'] = df250['time_min']

# %%
viz.velocity([df250], ['250nM K401-biotin + streptavidin'])#, x_limits=(-0.5, 80), y_limits=(10**(-22), 10**(-15)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\dalar\git\activedrops\code\exploratory\K401-Kif3-ActiveDROPS.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dalar/git/activedrops/code/exploratory/K401-Kif3-ActiveDROPS.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> viz.velocity([df250], ['250nM K401-biotin + streptavidin'])#, x_limits=(-0.5, 80), y_limits=(10**(-22), 10**(-15)))
#
# File c:\Users\dalar\git\activedrops\code\exploratory\../../activedrops\viz.py:79, in velocity(dfs, labels, filename, max_frame, x_limits, y_limits, logy, figsize)
#      76 df = df.iloc[:max_frame,:]
#      78 # Choose a color
# ---> 79 color = next(plt.gca()._get_lines.prop_cycler)['color']
#      81 ax.plot(df['time_min'], df['v (m/s)'] * 1e6, label=label, color=color)
#      82 ax.fill_between(df['time_min'], df['v (m/s)'] * 1e6, color=color, alpha=0.2)
#
# ...

# %% [markdown]
# **K401-mVenus-Avitag**

# %%
raw_piv_data =  "C:/Users/dalar/OneDrive/Desktop/current_experiment/100623-kva-cy5_gfp-beads-4x/3mint_1/piv/txt/PIVlab_****.txt"
processed_data = "C:/Users/dalar/OneDrive/Desktop/current_experiment/100623-kva-cy5_gfp-beads-4x/3mint_1/k401-L250.csv"

# pivdrops.process_piv_data(raw_piv_data, time_int=180, µl=2, L=250, save_path=processed_data, vmax=True, skip_frames=40)
kva = pd.read_csv(processed_data)
kva
# Out:
#      time_min       v (m/s)  index  vorticity (1/s)  divergence (1/s)  \
# 0         0.0  9.811769e-10      0     1.040786e-07      1.170785e-06
# 1         3.0  9.755036e-10      1     4.163717e-07      1.214483e-06
# 2         6.0  9.642780e-10      2     7.975691e-08      1.013036e-06
# 3         9.0  9.477466e-10      3     3.809934e-07      1.049174e-06
# 4        12.0  9.263433e-10      4     3.012788e-07      1.050344e-06
# ..        ...           ...    ...              ...               ...
# 638    1914.0  3.350682e-10    638     9.997231e-09     -4.872935e-08
# 639    1917.0  3.323843e-10    639    -2.513465e-07      1.023237e-07
# 640    1920.0  3.298467e-10    640    -3.519441e-07      3.870060e-08
# 641    1923.0  3.278650e-10    641    -1.475948e-07     -1.746020e-08
# 642    1926.0  3.267826e-10    642     1.833363e-07     -5.821017e-08
#
#      num_vectors  distance (m)     Power (W)      Work (J)
# 0          16129           NaN  3.080666e-23           NaN
# ...

# %%
viz.velocity([kva], ['K401-mVenus-Avitag'], x_limits=(-20, 2000), y_limits=(-.00125, 0.035))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\dalar\git\activedrops\code\exploratory\K401-Kif3-ActiveDROPS.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dalar/git/activedrops/code/exploratory/K401-Kif3-ActiveDROPS.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> viz.velocity([kva], ['K401-mVenus-Avitag'], x_limits=(-20, 2000), y_limits=(-.00125, 0.035))
#
# File c:\Users\dalar\git\activedrops\code\exploratory\../../activedrops\viz.py:79, in velocity(dfs, labels, filename, max_frame, x_limits, y_limits, logy, figsize)
#      76 df = df.iloc[:max_frame,:]
#      78 # Choose a color
# ---> 79 color = next(plt.gca()._get_lines.prop_cycler)['color']
#      81 ax.plot(df['time_min'], df['v (m/s)'] * 1e6, label=label, color=color)
#      82 ax.fill_between(df['time_min'], df['v (m/s)'] * 1e6, color=color, alpha=0.2)
#
# ...

# %%
dir_name = "C:/Users/dalar/OneDrive/Desktop/current_experiment/100623-kva-cy5_gfp-beads-4x/3mint_1/plots/"

viz.generate_image_sequence(
    dfs = [kva], 
    labels= ['K401-mVenus-Avitag'], 
    x_limits=(-20, 2000), y_limits=(-.00125, 0.035), figsize=(8,4),
    logy=False, 
    plot_type='velocity',
    dir_name=dir_name,
)

# %%
viz.distance([kva], ['K401-mVenus-Avitag'], x_limits=(-20, 2000), y_limits=(-0.5, 18))

# %%
dir_name = "C:/Users/dalar/OneDrive/Desktop/current_experiment/100623-kva-cy5_gfp-beads-4x/3mint_1/plots/"

viz.generate_image_sequence(
    dfs = [kva], 
    labels= ['K401-mVenus-Avitag'], 
    x_limits=(-20, 2000), y_limits=(-0.5, 18), figsize=(4,8),
    logy=False, 
    plot_type='distance',
    dir_name=dir_name,
)

# %%
viz.power([kva], ['K401-mVenus-Avitag'], x_limits=(-20, 2000), y_limits=((10**(-24), (10**(-19)))))

# %%
dir_name = "C:/Users/dalar/OneDrive/Desktop/current_experiment/100623-kva-cy5_gfp-beads-4x/3mint_1/plots/"

viz.generate_image_sequence(
    dfs = [kva], 
    labels= ['K401-mVenus-Avitag'], 
    x_limits=(-20, 2000), y_limits=((10**(-24), (10**(-19)))),
    logy=True, 
    plot_type='power',
    dir_name=dir_name,
)

# %% [markdown]
# **Kif3-mVenus-Avitag**

# %%
raw_piv_data =  "C:/Users/dalar/OneDrive/Desktop/current_experiment/100623-kif3va-cy5_gfp-beads-4x/3sint_1/txt/PIVlab_****.txt"
processed_data = "C:/Users/dalar/OneDrive/Desktop/current_experiment/100623-kif3va-cy5_gfp-beads-4x/3sint_1/kif3-L250.csv"

# pivdrops.process_piv_data(raw_piv_data, time_int=3, µl=2, L=250, save_path=processed_data, vmax=True, skip_frames=50)
kifva = pd.read_csv(processed_data)

# %%
viz.velocity(
    dfs = [kva, kifva], 
    labels= ['K401-mVenus-Avitag', 'Kif3-mVenus-Avitag'], 
    x_limits=(-20, 2000), y_limits=(10**(-4), 10**(1)), figsize=(8,4),
    logy=True, 

)

# %%
dir_name = "C:/Users/dalar/OneDrive/Desktop/current_experiment/100623-kva-cy5_gfp-beads-4x/3mint_1/plots_with_kva"

viz.generate_image_sequence(
    dfs = [kva, kifva], 
    labels= ['K401-mVenus-Avitag', 'Kif3-mVenus-Avitag'], 
    x_limits=(-20, 2000), y_limits=(10**(-4), 10**(1)), figsize=(8,4),
    logy=True, 
    plot_type='velocity',
    dir_name=dir_name,
)

# %%
viz.distance(
    dfs = [kva, kifva], 
    labels= ['K401-mVenus-Avitag', 'Kif3-mVenus-Avitag'], 
    x_limits=(-20, 2000), y_limits=(-1, 32), figsize=(4,8),
    logy=False, 

)

# %%
dir_name = "C:/Users/dalar/OneDrive/Desktop/current_experiment/100623-kva-cy5_gfp-beads-4x/3mint_1/plots_with_kifva"

viz.generate_image_sequence(
    dfs=[kva, kifva],
    plot_type='distance',
    dir_name=dir_name,
    labels=['K401-mVenus-Avitag', 'Kif3-mVenus-Avitag'],
    x_limits=(-20, 2000), y_limits=(-1, 32), figsize=(8,4),
    logy=False,
)

# %%
viz.power(
    dfs = [kva, kifva], 
    labels= ['K401-mVenus-Avitag', 'Kif3-mVenus-Avitag'], 
    x_limits=(-20, 2000), y_limits=(10**(-24), 10**(-15)), figsize=(8,4),
    logy=True, 

)

# %%
dir_name = "C:/Users/dalar/OneDrive/Desktop/current_experiment/100623-kva-cy5_gfp-beads-4x/3mint_1/plots_with_kva"

viz.generate_image_sequence(
    dfs = [kva, kifva], 
    labels= ['K401-mVenus-Avitag', 'Kif3-mVenus-Avitag'], 
    x_limits=(-20, 2000), y_limits=(10**(-24), 10**(-15)), figsize=(8,4),
    logy=True, 
    plot_type='power',
    dir_name=dir_name,
)

# %%
viz.velocity(
    dfs = [df250, kifva], 
    labels= ['250nM K401-biotin + streptavidin', 'Kif3-mVenus-Avitag'], 
    x_limits=(-1, 81), y_limits=(-.25, 5.5), figsize=(8,4),
    logy=False, 

)

# %%
dir_name = "C:/Users/dalar/OneDrive/Desktop/current_experiment/100623-kif3va-cy5_gfp-beads-4x/3sint_1/plots_with_kbio"

viz.generate_image_sequence(
    dfs = [df250, kifva], 
    labels= ['250nM K401-biotin + streptavidin', 'Kif3-mVenus-Avitag'], 
    x_limits=(-1, 81), y_limits=(-.25, 5.5), figsize=(8,4),
    logy=False, 
    plot_type='velocity',
    dir_name=dir_name,
)

# %%
viz.power(
    dfs = [df250, kifva], 
    labels= ['250nM K401-biotin + streptavidin', 'Kif3-mVenus-Avitag'], 
    x_limits=(-1, 81), y_limits=(10**(-21), 10**(-14)), figsize=(8,4),
    logy=True, 
)

# %%
dir_name = "C:/Users/dalar/OneDrive/Desktop/current_experiment/100623-kif3va-cy5_gfp-beads-4x/3sint_1/plots_with_kbio"

viz.generate_image_sequence(
    dfs = [df250, kifva], 
    labels= ['250nM K401-biotin + streptavidin', 'Kif3-mVenus-Avitag'], 
    x_limits=(-1, 81), y_limits=(10**(-21), 10**(-14)), figsize=(8,4),
    logy=True, 
    plot_type='power',
    dir_name=dir_name,
)

# %% [markdown]
# Now include control

# %%
viz.distance(
    dfs = [kva, kifva, df250], 
    labels= ['K401-mVenus-Avitag', 'Kif3-mVenus-Avitag', '250nM K401-biotin + streptavidin'], 
#     x_limits=(-20, 2000), y_limits=(10**(-24), 10**(-14)), figsize=(8,4),
    logy=True, 

)

# %%
viz.velocity([kva, kifva, df250], ['K401-mVenus-Avitag', 'Kif3-mVenus-Avitag', '250nM K401-biotin + streptavidin'])#, x_limits=(-0.5, 80), y_limits=(-0.05, 6))
viz.distance([kva, kifva, df250], ['K401-mVenus-Avitag', 'Kif3-mVenus-Avitag', '250nM K401-biotin + streptavidin'])#, x_limits=(-1, 85), y_limits=(-1, 180))
viz.power([kva, kifva, df250], ['K401-mVenus-Avitag', 'Kif3-mVenus-Avitag', '250nM K401-biotin + streptavidin'])#, x_limits=(-0.5, 80), y_limits=(10**(-25), 10**(-14)))
# viz.divergence([kifva], ['Kif3-mVenus-Avitag'])#, x_limits=(-4, 150), y_limits=(-0.0004, 0.0006))
# viz.vorticity([kifva], ['Kif3-mVenus-Avitag'])#, x_limits=(-4, 150), y_limits=(-0.0008, 0.00085))
