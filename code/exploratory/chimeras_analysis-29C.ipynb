# %%
## Import relevant libraries
import sys
import glob

sys.path.append('../../py_files/')
import quadrop as qd

# qd.set_plotting_style()

# %% [markdown]
# ### Data pre-procesing

# %%
# Example usage
base_dir = "../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/"
qd.consolidate_images(base_dir)
# Out:
# Consolidation appears to be already done. Directory '../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_' already exists with subfolders.

# %%
# Example usage
data_path = "../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/"

calibration_curve_paths = sorted(glob.glob("../../../../Thomson Lab Dropbox/David Larios/activedrops/main/calibration_curve/***ugml.tif"))


conditions_dict = {
    "A": "Pos0", 
    "B": "Pos1",
    "C": "Pos2",
    "D": "Pos3",
    "E": "Pos4", 
    "F": "Pos5",
    "G": "Pos6",
    "H": "Pos7",
    "negative": "Pos8"
}

# Organize PosX folders into condition folders
qd.organize_conditions(data_path, conditions_dict)

# Now run the existing functions to reorganize the tiffs and rename the folders
conditions, subconditions = qd.prepare_conditions(data_path)
time_interval_list = [40] * len(conditions)  # time intervals in seconds between frames for each condition

print("Conditions:", conditions)
print("Subconditions:", subconditions)
# Out:
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/Pos0 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/Pos1 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/Pos2 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/Pos3 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/Pos4 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/Pos5 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/Pos6 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/Pos7 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/Pos8 does not exist. Skipping.
# Conditions: ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'negative']
# Subconditions: ['Rep1']

# %%
qd.reorgTiffsToOriginal(data_path, conditions, subconditions)
# Out:
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/A/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/A/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/B/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/B/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/C/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/C/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/D/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/D/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/E/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/E/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/F/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/F/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/G/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/G/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/H/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/H/Rep1/original
# Moved .tif files from ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/negative/Rep1 to ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/negative/Rep1/original

# %% [markdown]
# ### Generate movies

# %%
# Call the function
qd.fluorescence_heatmap(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    time_interval_list=time_interval_list, 
    vmax=20, 
    skip_frames=128, 
    calibration_curve_paths=calibration_curve_paths, 
    show_scalebar=False,
    )

# %%
# Example usage
qd.create_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    frame_rate=30,
    skip_frames=1
    )

# %%
qd.create_combined_heatmap_movie_custom_grid(
    data_path, 
    conditions[:-1], 
    subconditions, 
    channel='cy5', 
    grid_rows=2, 
    grid_cols=4, 
    frame_rate=30,
    batch_size=50
    )

# %%
# Call the function
qd.fluorescence_heatmap(
    data_path, 
    conditions, 
    subconditions, 
    channel='GFP', 
    time_interval_list=time_interval_list, 
    vmax=500, 
    skip_frames=8, 
    calibration_curve_paths=calibration_curve_paths, 
    show_scalebar=True,
    )

# %%
# Example usage
qd.create_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel='GFP', 
    frame_rate=30,
    skip_frames=1
    )

# %%
qd.create_combined_heatmap_movie_custom_grid(
    data_path, 
    conditions[:-1], 
    subconditions, 
    channel='GFP', 
    grid_rows=2, 
    grid_cols=4, 
    frame_rate=60,
    batch_size=50
    )

# %%
qd.delete_temporary_image_directories(data_path, conditions, subconditions)

# %% [markdown]
# ### Fluorescence Quantification

# %%
# Example usage
mw_kda_list = [100] * len(conditions)
droplet_volume_list = [2] * len(conditions)
protein_lengths_list = [500] * len(conditions)  # Assuming 500 amino acids per protein

qd.quantify_tiffiles(
    data_path, 
    conditions, 
    subconditions, 
    calibration_curve_paths, 
    mw_kda_list, 
    droplet_volume_list, 
    time_interval_list, 
    protein_lengths_list,
    ribosome_count=10**10,
    skip_frames=1,
    subtract_negative=True
)
# Out:
# Calculating sample intensities: 100%|██████████| 2016/2016 [00:02<00:00, 779.84it/s]
# Calculating sample intensities: 100%|██████████| 2016/2016 [00:02<00:00, 772.75it/s]
# Calculating sample intensities: 100%|██████████| 2016/2016 [00:02<00:00, 781.65it/s]
# Calculating sample intensities: 100%|██████████| 2016/2016 [00:02<00:00, 771.81it/s]
# Calculating sample intensities: 100%|██████████| 2016/2016 [00:03<00:00, 631.13it/s]
# Calculating sample intensities: 100%|██████████| 2016/2016 [00:02<00:00, 781.64it/s]
# Calculating sample intensities: 100%|██████████| 2016/2016 [00:02<00:00, 778.82it/s]
# Calculating sample intensities: 100%|██████████| 2016/2016 [00:02<00:00, 773.81it/s]
# Calculating sample intensities: 100%|██████████| 2016/2016 [00:02<00:00, 811.73it/s]
# ('../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/combined_expression.csv',
#  '../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/mean_expression.csv')

# %% [markdown]
# ### PIV pre-processing

# %%
qd.split_tiffs(data_path, ['H'], subconditions, channel='cy5', file_interval=1)

# %% [markdown]
# ### PIV

# %%
# Define feature limits and other parameters
v = 2E-7
velocity_limits = (0, v)
other_limits = (-0.0005, 0.0005)
skip_frames = 1 ### CHANGE THIS TO SKIP FRAMES


velocity_limits = (None, None)
other_limits = (None, None)


feature_limits = {
    # 'u [m/s]': (-v, v), 
    # 'v [m/s]': (-v, v), 
    # 'data type [-]': (None, None),
    'velocity magnitude [m/s]': velocity_limits,
    'vorticity [1/s]': other_limits,
    'divergence [1/s]': other_limits,
    # 'dcev [1]': (0, 250),
    'shear [1/s]': other_limits,
    'strain [1/s]': other_limits,
    'vector direction [degrees]': (-180, 180),
}


# Features for PCA and plotting
features_pca = [
    "vorticity [1/s]_mean",
    "velocity magnitude [um/s]",
    "distance [m]_mean",
    "divergence [1/s]_mean",
    "shear [1/s]_mean",
    "strain [1/s]_mean",
    "correlation length [um]", 
    "power [W]_mean",
    "work [J]",
]

# %%
time_interval_list = [40, 40, 40, 40, 40]  # time intervals in seconds between frames for each condition


# Process PIV data
qd.process_piv_data(
    data_path, 
    ["A", "C", "D", "E", "H"], 
    subconditions, 
    feature_limits, 
    time_interval_list, 
    min_frame=0, 
    max_frame=None, 
    skip_frames=1, 
    plot_autocorrelation=False, 
    frame_rate=1, 
    heatmaps=False
    )
# Out:
# Processing PIV data:   0%|          | 0/5 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  20%|██        | 1/5 [00:22<01:31, 22.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  40%|████      | 2/5 [00:46<01:10, 23.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  60%|██████    | 3/5 [01:09<00:46, 23.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  80%|████████  | 4/5 [01:33<00:23, 23.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data: 100%|██████████| 5/5 [01:57<00:00, 23.41s/it]

# %%
# Plot features and PCA
qd.plot_PIV_features(
    data_path, 
    ["A", "C", "D", "E", "H"], 
    subconditions, 
    features_pca, 
    min_frame=0, 
    max_frame=None
    )
# Out:
# Plotting PIV features: 100%|██████████| 5/5 [00:08<00:00,  1.70s/it]

# %%
# Plot features and PCA
qd.plot_PIV_features_averaged(
    data_path, 
    ["A", "C", "D", "E", "H"], 
    features_pca, 
    min_frame=0, 
    max_frame=None
    )
# Out:
# Plotting averaged PIV features: 100%|██████████| 5/5 [00:06<00:00,  1.39s/it]

# %%
# Plot features and PCA
qd.plot_PIV_features_combined(
    data_path, 
    ["A", "C", "D", "E", "H"], 
    features_pca, 
    min_frame=0, 
    max_frame=None
    )
# Out:
# Collecting PIV data: 100%|██████████| 5/5 [00:00<00:00, 178.25it/s]

# %%
# Plot features and PCA
qd.plot_PIV_features_all_conditions_subconditions(
    data_path, 
    ["A", "C", "D", "E", "H"], 
    subconditions, 
    features_pca, 
    min_frame=0, 
    max_frame=None
    )

# %% [markdown]
# ### Expression + PIV

# %%
# Combine the data and save it to the "output_data" directory
qd.combine_averaged_dataframes(data_path, conditions, subconditions)
# Out:
# Conditions:   0%|          | 0/9 [00:00<?, ?it/s]
# 'Averaged' folder not found for B/Rep1. Skipping...
# 'Averaged' folder not found for F/Rep1. Skipping...
# 'Averaged' folder not found for G/Rep1. Skipping...
# Conditions: 100%|██████████| 9/9 [00:00<00:00, 125.92it/s]
# 'Averaged' folder not found for negative/Rep1. Skipping...
# Combined DataFrame saved to: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/combined_PIV.csv

# %%
qd.merge_expression_piv_data(data_path)
# Out:
# Merged DataFrame saved to: ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/merged_expression_PIV.csv

# %%
# Specify the columns you want to plot
x_column = "Protein Concentration_nM"  # Example x-axis column
y_column = "velocity magnitude [m/s]_mean"  # Example y-axis column

# Apply Gaussian smoothing with sigma_x=2 and sigma_y=1
qd.plot_columns(data_path, x_column, y_column, sigma_x=1, sigma_y=1)
# Out:
# Plot saved for condition A at ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/expression_piv_plots/Protein_Concentration_nM_vs_velocity_magnitude_m_s_mean_A.png
# Plot saved for condition B at ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/expression_piv_plots/Protein_Concentration_nM_vs_velocity_magnitude_m_s_mean_B.png
# Plot saved for condition C at ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/expression_piv_plots/Protein_Concentration_nM_vs_velocity_magnitude_m_s_mean_C.png
# Plot saved for condition D at ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/expression_piv_plots/Protein_Concentration_nM_vs_velocity_magnitude_m_s_mean_D.png
# Plot saved for condition E at ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/expression_piv_plots/Protein_Concentration_nM_vs_velocity_magnitude_m_s_mean_E.png
# Plot saved for condition F at ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/expression_piv_plots/Protein_Concentration_nM_vs_velocity_magnitude_m_s_mean_F.png
# Plot saved for condition G at ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/expression_piv_plots/Protein_Concentration_nM_vs_velocity_magnitude_m_s_mean_G.png
# Plot saved for condition H at ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/expression_piv_plots/Protein_Concentration_nM_vs_velocity_magnitude_m_s_mean_H.png
# Plot saved for condition negative at ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/expression_piv_plots/Protein_Concentration_nM_vs_velocity_magnitude_m_s_mean_negative.png
# Combined plot saved at ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/expression_piv_plots/Protein_Concentration_nM_vs_velocity_magnitude_m_s_mean_All_Conditions.png

# %%
# List of features for PCA
features_pca = [
    "vorticity [1/s]_mean",
    "velocity magnitude [m/s]_mean",
    # "distance [m]_mean",
    "divergence [1/s]_mean",
    # "shear [1/s]_mean",
    # "strain [1/s]_mean",
    "correlation length [m]_mean", 
    # "power [W]_mean",
    "Protein Concentration_nM"  # Example of adding protein concentration to the PCA
]

# Run PCA and save plot (with all conditions and subconditions in the same plot)
qd.plot_pca_expression_piv(data_path, conditions=conditions, subconditions=subconditions, features=features_pca, sigma=1)
# Out:
# Available columns in the DataFrame: Index(['condition', 'subcondition', 'time (s)', 'Time_min', 'Time_h',
#        'Mean Intensity', 'Protein Concentration_ng_ul',
#        'Protein Concentration_nM', 'Number of Protein Molecules',
#        'Rate of Change of Protein Molecules per Second',
#        'Translation Rate aa_s', 'Unnamed: 0', 'frame', 'x [m]_mean',
#        'y [m]_mean', 'u [m/s]_mean', 'v [m/s]_mean', 'data type [-]_mean',
#        'vorticity [1/s]_mean', 'velocity magnitude [m/s]_mean',
#        'divergence [1/s]_mean', 'dcev [1]_mean', 'shear [1/s]_mean',
#        'strain [1/s]_mean', 'vector direction [degrees]_mean',
#        'correlation length [m]_mean', 'distance [m]_mean', 'power [W]_mean',
#        'time (min)', 'time (h)'],
#       dtype='object')
# Warning: Not enough valid samples for B and Rep1. Skipping...
# Warning: Not enough valid samples for F and Rep1. Skipping...
# Warning: Not enough valid samples for G and Rep1. Skipping...
# Warning: Not enough valid samples for negative and Rep1. Skipping...
# PCA plot with gradient lines saved at ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/expression_piv_plots/PCA_plot_all_conditions_gradient.jpg
# Individual PCA plot for A_Rep1 saved at ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/expression_piv_plots/PCA_plot_A_Rep1_gradient.jpg
# Warning: Not enough valid samples for B and Rep1. Skipping...
# Individual PCA plot for C_Rep1 saved at ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/expression_piv_plots/PCA_plot_C_Rep1_gradient.jpg
# Individual PCA plot for D_Rep1 saved at ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/expression_piv_plots/PCA_plot_D_Rep1_gradient.jpg
# Individual PCA plot for E_Rep1 saved at ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/expression_piv_plots/PCA_plot_E_Rep1_gradient.jpg
# Warning: Not enough valid samples for F and Rep1. Skipping...
# Warning: Not enough valid samples for G and Rep1. Skipping...
# Individual PCA plot for H_Rep1 saved at ../../../../Thomson Lab Dropbox/David Larios/activedrops/main/090124-chimeras100nM_29C/2p5ul_TMBmix-1ulDNA100nM_/output_data/expression_piv_plots/PCA_plot_H_Rep1_gradient.jpg
# Warning: Not enough valid samples for negative and Rep1. Skipping...

# %%
# Example usage
qd.delete_outputs(data_path, conditions, subconditions, output_dirs=None)
