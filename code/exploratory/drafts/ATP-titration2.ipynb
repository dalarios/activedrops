# %%
## Import relevant libraries
import sys
import os
import shutil
sys.path.append('../../activedrops')

## Including ourselves
import quadrop as qd
qd.set_plotting_style()

# %%
data_path = "../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = sorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = sorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])
subconditions
# Out:
# ['Pos0', 'Pos1', 'Pos2']

# %%
def reorgTiffsToOriginal(data_path, conditions, subconditions):
    """
    Args:
        data_path (_type_): _description_
        conditions (_type_): _description_
        subconditions (_type_): _description_
        
        
    Activate when you have your subconditions inside the conditions folder. 
    This function renames the subconditions as PosX and moves the raw data do "original" folder.
    """
    
    
    for condition in conditions:
        # Get the actual subconditions in the directory
        actual_subconditions = [name for name in os.listdir(os.path.join(data_path, condition)) if os.path.isdir(os.path.join(data_path, condition, name))]
        
        # Rename the actual subconditions to match the subconditions in your list
        for i, actual_subcondition in enumerate(sorted(actual_subconditions)):
            os.rename(os.path.join(data_path, condition, actual_subcondition), os.path.join(data_path, condition, subconditions[i]))
        
        for subcondition in subconditions:
            # Construct the path to the subcondition directory
            subcondition_path = os.path.join(data_path, condition, subcondition)
            
            # Create the path for the "original" directory within the subcondition directory
            original_dir_path = os.path.join(subcondition_path, "original")
            
            # Always create the "original" directory
            os.makedirs(original_dir_path, exist_ok=True)
            
            # Iterate over all files in the subcondition directory
            for filename in os.listdir(subcondition_path):
                # Check if the file is a .tif file
                if filename.endswith(".tif"):
                    # Construct the full path to the file
                    file_path = os.path.join(subcondition_path, filename)
                    
                    # Construct the path to move the file to
                    destination_path = os.path.join(original_dir_path, filename)
                    
                    # Move the file to the "original" directory
                    shutil.move(file_path, destination_path)
            print(f"Moved .tif files from {subcondition_path} to {original_dir_path}")


reorgTiffsToOriginal(data_path, conditions, subconditions)
# Out:
# Moved .tif files from ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/20MT-0mM_ATP/Pos0 to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/20MT-0mM_ATP/Pos0/original
# Moved .tif files from ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/20MT-0mM_ATP/Pos1 to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/20MT-0mM_ATP/Pos1/original
# Moved .tif files from ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/20MT-0mM_ATP/Pos2 to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/20MT-0mM_ATP/Pos2/original
# Moved .tif files from ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/20MT-3mM_ATP/Pos0 to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/20MT-3mM_ATP/Pos0/original
# Moved .tif files from ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/20MT-3mM_ATP/Pos1 to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/20MT-3mM_ATP/Pos1/original
# Moved .tif files from ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/20MT-3mM_ATP/Pos2 to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/20MT-3mM_ATP/Pos2/original
# Moved .tif files from ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/20MT-7mM_ATP/Pos0 to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/20MT-7mM_ATP/Pos0/original
# Moved .tif files from ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/20MT-7mM_ATP/Pos1 to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/20MT-7mM_ATP/Pos1/original
# Moved .tif files from ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/20MT-7mM_ATP/Pos2 to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/20MT-7mM_ATP/Pos2/original
# Moved .tif files from ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/noMT-0mM_ATP/Pos0 to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/noMT-0mM_ATP/Pos0/original
# Moved .tif files from ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/noMT-0mM_ATP/Pos1 to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/noMT-0mM_ATP/Pos1/original
# Moved .tif files from ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/noMT-0mM_ATP/Pos2 to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/noMT-0mM_ATP/Pos2/original
# Moved .tif files from ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/noMT-3mM_ATP/Pos0 to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/noMT-3mM_ATP/Pos0/original
# Moved .tif files from ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/noMT-3mM_ATP/Pos1 to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/noMT-3mM_ATP/Pos1/original
# Moved .tif files from ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/noMT-3mM_ATP/Pos2 to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/noMT-3mM_ATP/Pos2/original
# Moved .tif files from ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/noMT-7mM_ATP/Pos0 to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/noMT-7mM_ATP/Pos0/original
# Moved .tif files from ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/noMT-7mM_ATP/Pos1 to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/noMT-7mM_ATP/Pos1/original
# Moved .tif files from ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/noMT-7mM_ATP/Pos2 to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/noMT-7mM_ATP/Pos2/original

# %%
# frame info
min_frame = 0
max_frame = 250
skip_frames=8
frame_rate=30
time_intervals = [30] * len(conditions)

# %%
# Call the function with the updated parameters
qd.plot_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="cy5",
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False,  # Set log_scale to True
    timescale="min"
)

# %%
# Call the function with the updated parameters
qd.plot_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions[3:],
    subconditions=subconditions,
    channel="gfp",
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False,  # Set log_scale to True
    timescale="min"
)

# %%
# Call the function with the updated parameters
qd.plot_average_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions[3:],
    subconditions=subconditions,
    channel="gfp",
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False,  # Set log_scale to True
    timescale="min"
)

# %%
conditions_MT = conditions[:3]
conditions_MT
# Out:
# ['20MT-0mM_ATP', '20MT-3mM_ATP', '20MT-7mM_ATP']

# %%
# Example usage
conditions_MT = conditions[:3]

# frame info
min_frame = 0
max_frame = None
skip_frames=4
frame_rate=30
time_intervals = [30, 30, 30]

# channel info
channel = "cy5"
vmax = 0.2

qd.single_fluorescence_movies(data_path, conditions_MT, subconditions, channel, time_intervals, min_frame, max_frame, vmax, skip_frames, frame_rate)
# Out:
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_cy5/20MT-0mM_ATP_Pos0-cy5.avi
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_cy5/20MT-0mM_ATP_Pos1-cy5.avi
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_cy5/20MT-0mM_ATP_Pos2-cy5.avi
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 15
#      12 channel = "cy5"
#      13 vmax = 0.2
# ---> 15 qd.single_fluorescence_movies(data_path, conditions_MT, subconditions, channel, time_intervals, min_frame, max_frame, vmax, skip_frames, frame_rate)
#
# File ~/git/activedrops/code/exploratory/../../activedrops/quadrop.py:463, in single_fluorescence_movies(data_path, conditions, subconditions, channel, time_intervals, min_frame, max_frame, vmax, skip_frames, frame_rate)
#     450 fluorescence_heatmap(
#     451     data_path=data_path,
#     452     condition=condition,
#    (...)
#     459     skip_frames=skip_frames
#     460 )
#     462 # Create annotated image movies for each condition and subcondition
# --> 463 create_movies(
#     464     data_path=data_path,
#     465     condition=condition,
#     466     subcondition=subcondition,
#     467     channel=channel,
#     468     movie_type='single',
#     469     frame_rate=frame_rate,
#     470     max_frame=max_frame
#     471 )
#
# File ~/git/activedrops/code/exploratory/../../activedrops/quadrop.py:438, in create_movies(data_path, condition, subcondition, channel, movie_type, frame_rate, feature_limits, max_frame)
#     435 out = cv2.VideoWriter(out_path, fourcc, frame_rate, video_resolution)
#     437 for file_path in image_files:
# --> 438     img = cv2.imread(file_path)
#     439     out.write(img)  # Write the image frame to the video
#     441 out.release()
#
# KeyboardInterrupt:

# %%
qd.grid_heatmaps(data_path, conditions_MT, subconditions, channel, frame_rate=frame_rate, figsize=(20,24))
# Out:
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/grid-cy5.avi

# %%
# channel info
channel = "gfp"
vmax = 0.02

qd.single_fluorescence_movies(data_path, conditions_MT, subconditions, channel, time_intervals, min_frame, max_frame, vmax, skip_frames, frame_rate)
# Out:
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_gfp/20MT-0mM_ATP_Pos0-gfp.avi
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_gfp/20MT-0mM_ATP_Pos1-gfp.avi
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_gfp/20MT-0mM_ATP_Pos2-gfp.avi
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_gfp/20MT-3mM_ATP_Pos0-gfp.avi
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_gfp/20MT-3mM_ATP_Pos1-gfp.avi
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_gfp/20MT-3mM_ATP_Pos2-gfp.avi
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_gfp/20MT-7mM_ATP_Pos0-gfp.avi
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_gfp/20MT-7mM_ATP_Pos1-gfp.avi
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_gfp/20MT-7mM_ATP_Pos2-gfp.avi

# %%
qd.grid_heatmaps(data_path, conditions_MT, subconditions, channel, frame_rate=frame_rate, figsize=(20,24))
# Out:
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/grid-gfp.avi

# %%
# frame info
min_frame = 0
max_frame = None
skip_frames=4
frame_rate=30
time_intervals = [30, 30, 30]

# channel info
channel = "gfp"
vmax = 0.02

qd.single_fluorescence_movies(data_path, conditions[3:], subconditions, channel, time_intervals, min_frame, max_frame, vmax, skip_frames, frame_rate)
# Out:
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_gfp/noMT-0mM_ATP_Pos0-gfp.avi
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_gfp/noMT-0mM_ATP_Pos1-gfp.avi
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_gfp/noMT-0mM_ATP_Pos2-gfp.avi
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_gfp/noMT-3mM_ATP_Pos0-gfp.avi
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_gfp/noMT-3mM_ATP_Pos1-gfp.avi
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_gfp/noMT-3mM_ATP_Pos2-gfp.avi
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_gfp/noMT-7mM_ATP_Pos0-gfp.avi
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_gfp/noMT-7mM_ATP_Pos1-gfp.avi
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/single_movies_gfp/noMT-7mM_ATP_Pos2-gfp.avi

# %%
qd.grid_heatmaps(data_path, conditions[3:], subconditions, channel, frame_rate=frame_rate, figsize=(20,24))
# Out:
# Video saved to ../../data/20uM_MT-40nM_DNA-ATP-cy5_gfp/grid-gfp.avi
