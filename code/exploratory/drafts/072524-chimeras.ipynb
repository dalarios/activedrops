# %%
## Import relevant libraries
import sys
import os
import shutil
from natsort import natsorted  # For natural sorting
sys.path.append('../../activedrops')

## Including ourselves
import quadrop as qd
qd.set_plotting_style()

import glob
import imageio
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data_path = "../../data/chimeras/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])[:-1]

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])

conditions
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']

# %%
qd.reorgTiffsToOriginal(data_path, conditions, subconditions)
# Out:
# Moved .tif files from ../../data/chimeras/A\Pos0 to ../../data/chimeras/A\Pos0\original
# Moved .tif files from ../../data/chimeras/B\Pos0 to ../../data/chimeras/B\Pos0\original
# Moved .tif files from ../../data/chimeras/C\Pos0 to ../../data/chimeras/C\Pos0\original
# Moved .tif files from ../../data/chimeras/D\Pos0 to ../../data/chimeras/D\Pos0\original
# Moved .tif files from ../../data/chimeras/E\Pos0 to ../../data/chimeras/E\Pos0\original
# Moved .tif files from ../../data/chimeras/F\Pos0 to ../../data/chimeras/F\Pos0\original
# Moved .tif files from ../../data/chimeras/G\Pos0 to ../../data/chimeras/G\Pos0\original
# Moved .tif files from ../../data/chimeras/H\Pos0 to ../../data/chimeras/H\Pos0\original

# %%
# channel info
channel = "gfp"
min_frame = 0
max_frame = None
skip_frames=8
frame_rate=30
time_intervals = [60] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True
)

# %%
# frame info
min_frame = 0
max_frame = None
skip_frames=4
frame_rate=15
time_intervals = [180] * len(conditions) 

# channel info
channel = "cy5"
vmax = 0.14


qd.single_fluorescence_movies(data_path, conditions, subconditions, channel, time_intervals, min_frame, max_frame, vmax, skip_frames, frame_rate)
# Out:
# Video saved to ../../data/chimeras/single_movies_cy5\A_Pos0-cy5.avi
# Video saved to ../../data/chimeras/single_movies_cy5\B_Pos0-cy5.avi
# Video saved to ../../data/chimeras/single_movies_cy5\C_Pos0-cy5.avi
# Video saved to ../../data/chimeras/single_movies_cy5\D_Pos0-cy5.avi
# Video saved to ../../data/chimeras/single_movies_cy5\E_Pos0-cy5.avi
# Video saved to ../../data/chimeras/single_movies_cy5\F_Pos0-cy5.avi
# Video saved to ../../data/chimeras/single_movies_cy5\G_Pos0-cy5.avi
# Video saved to ../../data/chimeras/single_movies_cy5\H_Pos0-cy5.avi

# %%
figsize=(16, 12)


qd.grid_heatmaps(data_path, conditions, subconditions, "cy5", frame_rate=frame_rate, figsize=figsize)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[38], line 4
#       1 figsize=(16, 12)
# ----> 4 qd.grid_heatmaps(data_path, conditions, subconditions, "cy5", frame_rate=frame_rate, figsize=figsize)
#
# File c:\Users\Admin\git\activedrops\code\exploratory\../../activedrops\quadrop.py:457, in grid_heatmaps(data_path, conditions, subconditions, channel, frame_rate, figsize)
#     455 if os.path.exists(image_path):
#     456     im = imageio.imread(image_path)
# --> 457     ax[i, j].imshow(im, cmap='gray')
#     458     ax[i, j].axis('off')
#     459 else:
#     460     # Handle missing files (optional) by clearing or placing a placeholder
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
conditions
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']

# %%
data_path = "../../data/species/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])

conditions
# Out:
# ['1-TiLa']

# %%
qd.reorgTiffsToOriginal(data_path, conditions, subconditions)
# Out:
# Moved .tif files from ../../data/species/1-TiLa\Pos0 to ../../data/species/1-TiLa\Pos0\original

# %%
# channel info
channel = "gfp"
min_frame = 0
max_frame = None
skip_frames=8
frame_rate=30
time_intervals = [60] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True
)

# %%
# frame info
min_frame = 0
max_frame = None
skip_frames=8
frame_rate=15
time_intervals = [120] * len(conditions) 

# channel info
channel = "cy5"
vmax = 0.2


qd.single_fluorescence_movies(data_path, conditions, subconditions, channel, time_intervals, min_frame, max_frame, vmax, skip_frames, frame_rate)
# Out:
# Video saved to ../../data/species/single_movies_cy5\1-TiLa_Pos0-cy5.avi
