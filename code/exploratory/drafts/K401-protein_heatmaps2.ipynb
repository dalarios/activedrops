# %%
import sys
sys.path.append('../../activedrops')
import os
import pandas as pd
import viz
import pivdrops

viz.set_plotting_style()

# %%
input_dir = 'C:/Users/dalar/OneDrive/Desktop/current_experiment/100223-kbio-500_250_125nM/pos1-250nM/piv-pos1-250nM/txt-250nM/'
output_dir = 'C:/Users/dalar/OneDrive/Desktop/current_experiment/100223-kbio-500_250_125nM/pos1-250nM/heatmaps/'

viz.plot_feature_heatmaps(['velocity'], input_dir, output_dir, display_single_frame=True)
# Out:
# 'Displayed the heatmap for the first frame in the notebook!'

# %% [markdown]
# look at this txt file. It is one of many that correspond to PIV analysis of a movie frame. I'll show you a txt file, which contains the coordinates per pixel and values of different features like veloicity, vorticity, divergence, etc. I need your help because I need to obtain the two point correlation function, but I don't understand how to do it, my boss said it had to do with fitting to an exponential. Can you help me? I'm sharing a txt file that is in a folder of all the txt files corresponding to frames
