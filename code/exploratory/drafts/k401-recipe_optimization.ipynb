# %%
## Import relevant libraries
import sys
import os
import shutil
from natsort import natsorted  # For natural sorting
sys.path.append('../../activedrops')

## Including ourselves
import quadrop as qd
qd.set_plotting_style()

# %%
data_path = "../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])

subconditions
# Out:
# ['Pos12', 'Pos13']

# %%
def reorgTiffsToOriginal(data_path, conditions, subconditions):
    """
    Args:
        data_path (_type_): _description_
        conditions (_type_): _description_
        subconditions (_type_): _description_
        
        
    Activate when you have your subconditions inside the conditions folder. 
    This function renames the subconditions as PosX and moves the raw data do "original" folder.
    """
    
    
    for condition in conditions:
        # Get the actual subconditions in the directory
        actual_subconditions = [name for name in os.listdir(os.path.join(data_path, condition)) if os.path.isdir(os.path.join(data_path, condition, name))]
        
        # Rename the actual subconditions to match the subconditions in your list
        for i, actual_subcondition in enumerate(sorted(actual_subconditions)):
            os.rename(os.path.join(data_path, condition, actual_subcondition), os.path.join(data_path, condition, subconditions[i]))
        
        for subcondition in subconditions:
            # Construct the path to the subcondition directory
            subcondition_path = os.path.join(data_path, condition, subcondition)
            
            # Create the path for the "original" directory within the subcondition directory
            original_dir_path = os.path.join(subcondition_path, "original")
            
            # Always create the "original" directory
            os.makedirs(original_dir_path, exist_ok=True)
            
            # Iterate over all files in the subcondition directory
            for filename in os.listdir(subcondition_path):
                # Check if the file is a .tif file
                if filename.endswith(".tif"):
                    # Construct the full path to the file
                    file_path = os.path.join(subcondition_path, filename)
                    
                    # Construct the path to move the file to
                    destination_path = os.path.join(original_dir_path, filename)
                    
                    # Move the file to the "original" directory
                    shutil.move(file_path, destination_path)
            print(f"Moved .tif files from {subcondition_path} to {original_dir_path}")


reorgTiffsToOriginal(data_path, conditions, subconditions)
# Out:
# Moved .tif files from ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/5ul-biotin/Pos12 to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/5ul-biotin/Pos12/original
# Moved .tif files from ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/5ul-biotin/Pos13 to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/5ul-biotin/Pos13/original
# Moved .tif files from ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/5ul-m2b/Pos12 to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/5ul-m2b/Pos12/original
# Moved .tif files from ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/5ul-m2b/Pos13 to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/5ul-m2b/Pos13/original
# Moved .tif files from ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/5ul-peg/Pos12 to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/5ul-peg/Pos12/original
# Moved .tif files from ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/5ul-peg/Pos13 to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/5ul-peg/Pos13/original
# Moved .tif files from ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/6ul-biotin/Pos12 to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/6ul-biotin/Pos12/original
# Moved .tif files from ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/6ul-biotin/Pos13 to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/6ul-biotin/Pos13/original
# Moved .tif files from ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/6ul-m2b/Pos12 to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/6ul-m2b/Pos12/original
# Moved .tif files from ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/6ul-m2b/Pos13 to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/6ul-m2b/Pos13/original
# Moved .tif files from ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/6ul-peg/Pos12 to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/6ul-peg/Pos12/original
# Moved .tif files from ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/6ul-peg/Pos13 to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/6ul-peg/Pos13/original
# Moved .tif files from ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/7ul-biotin/Pos12 to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/7ul-biotin/Pos12/original
# Moved .tif files from ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/7ul-biotin/Pos13 to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/7ul-biotin/Pos13/original
# Moved .tif files from ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/7ul-m2b/Pos12 to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/7ul-m2b/Pos12/original
# Moved .tif files from ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/7ul-m2b/Pos13 to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/7ul-m2b/Pos13/original
# Moved .tif files from ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/7ul-peg/Pos12 to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/7ul-peg/Pos12/original
# Moved .tif files from ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/7ul-peg/Pos13 to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/7ul-peg/Pos13/original

# %%
# frame info
min_frame = 0
max_frame = None
skip_frames=32
frame_rate=30
time_intervals = [300] * len(conditions)

# %%
# Call the function with the updated parameters
qd.plot_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="gfp",
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False,  # Set log_scale to True
    timescale="h"
)

# %%
# Call the function with the updated parameters
qd.plot_average_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="gfp",
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False,  # Set log_scale to True
    timescale="h"
)

# %%
# frame info
min_frame = 0
max_frame = None
skip_frames=8
frame_rate=30

# channel info
channel = "cy5"
vmax = 0.5

qd.single_fluorescence_movies(data_path, conditions, subconditions, channel, time_intervals, min_frame, max_frame, vmax, skip_frames, frame_rate)
# Out:
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/single_movies_cy5/5ul-biotin_Pos12-cy5.avi
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/single_movies_cy5/5ul-biotin_Pos13-cy5.avi
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/single_movies_cy5/5ul-m2b_Pos12-cy5.avi
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/single_movies_cy5/5ul-m2b_Pos13-cy5.avi
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/single_movies_cy5/5ul-peg_Pos12-cy5.avi
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/single_movies_cy5/5ul-peg_Pos13-cy5.avi
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/single_movies_cy5/6ul-biotin_Pos12-cy5.avi
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/single_movies_cy5/6ul-biotin_Pos13-cy5.avi
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/single_movies_cy5/6ul-m2b_Pos12-cy5.avi
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/single_movies_cy5/6ul-m2b_Pos13-cy5.avi
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/single_movies_cy5/6ul-peg_Pos12-cy5.avi
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/single_movies_cy5/6ul-peg_Pos13-cy5.avi
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/single_movies_cy5/7ul-biotin_Pos12-cy5.avi
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/single_movies_cy5/7ul-biotin_Pos13-cy5.avi
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/single_movies_cy5/7ul-m2b_Pos12-cy5.avi
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/single_movies_cy5/7ul-m2b_Pos13-cy5.avi
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/single_movies_cy5/7ul-peg_Pos12-cy5.avi
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/single_movies_cy5/7ul-peg_Pos13-cy5.avi

# %%
subconditions[:1]
# Out:
# ['Pos12']

# %%
qd.grid_heatmaps(data_path, conditions[::1], subconditions, channel, frame_rate=frame_rate, figsize=(20,8))
# Out:
# Video saved to ../../data/k401-recipe-optimization/2drops-cy5_50ms-gfp_50ms-300sint_8/grid-cy5.avi

# %%
# frame info
min_frame = 0
max_frame = None
skip_frames=32
frame_rate=30
time_intervals = [300] * len(conditions[::3])

# %%
# Call the function with the updated parameters
qd.plot_average_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions[2::3],
    subconditions=subconditions,
    channel="gfp",
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False,  # Set log_scale to True
    timescale="min"
)
