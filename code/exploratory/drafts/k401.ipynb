# %%
## Import relevant libraries
import sys
import os
import shutil
sys.path.append('../../activedrops')
import pivdrops
import viz
pivdrops.set_plotting_style()

# %%
def reorgTiffsToOriginal(data_path, conditions, subconditions):
    for condition in conditions:
        # Get the actual subconditions in the directory
        actual_subconditions = [name for name in os.listdir(os.path.join(data_path, condition)) if os.path.isdir(os.path.join(data_path, condition, name))]
        
        # Rename the actual subconditions to match the subconditions in your list
        for i, actual_subcondition in enumerate(sorted(actual_subconditions)):
            os.rename(os.path.join(data_path, condition, actual_subcondition), os.path.join(data_path, condition, subconditions[i]))
        
        for subcondition in subconditions:
            # Construct the path to the subcondition directory
            subcondition_path = os.path.join(data_path, condition, subcondition)
            
            # Create the path for the "original" directory within the subcondition directory
            original_dir_path = os.path.join(subcondition_path, "original")
            
            # Always create the "original" directory
            os.makedirs(original_dir_path, exist_ok=True)
            
            # Iterate over all files in the subcondition directory
            for filename in os.listdir(subcondition_path):
                # Check if the file is a .tif file
                if filename.endswith(".tif"):
                    # Construct the full path to the file
                    file_path = os.path.join(subcondition_path, filename)
                    
                    # Construct the path to move the file to
                    destination_path = os.path.join(original_dir_path, filename)
                    
                    # Move the file to the "original" directory
                    shutil.move(file_path, destination_path)
            print(f"Moved .tif files from {subcondition_path} to {original_dir_path}")

# %%
# Example usage
data_path = "../../data/031124-k401-100nM_50nM/microtubules/"
conditions = [
    'DNA_100nM',
    'DNA_50nM'
]
subconditions = ["Pos0", "Pos1", "Pos2"]
min_frame = 0
max_frame = None
time_interval=30
skip_frames=4
frame_rate=30

reorgTiffsToOriginal(data_path, conditions, subconditions)
# Out:
# Moved .tif files from ../../data/031124-k401-100nM_50nM/microtubules/DNA_100nM\Pos0 to ../../data/031124-k401-100nM_50nM/microtubules/DNA_100nM\Pos0\original
# Moved .tif files from ../../data/031124-k401-100nM_50nM/microtubules/DNA_100nM\Pos1 to ../../data/031124-k401-100nM_50nM/microtubules/DNA_100nM\Pos1\original
# Moved .tif files from ../../data/031124-k401-100nM_50nM/microtubules/DNA_100nM\Pos2 to ../../data/031124-k401-100nM_50nM/microtubules/DNA_100nM\Pos2\original
# Moved .tif files from ../../data/031124-k401-100nM_50nM/microtubules/DNA_50nM\Pos0 to ../../data/031124-k401-100nM_50nM/microtubules/DNA_50nM\Pos0\original
# Moved .tif files from ../../data/031124-k401-100nM_50nM/microtubules/DNA_50nM\Pos1 to ../../data/031124-k401-100nM_50nM/microtubules/DNA_50nM\Pos1\original
# Moved .tif files from ../../data/031124-k401-100nM_50nM/microtubules/DNA_50nM\Pos2 to ../../data/031124-k401-100nM_50nM/microtubules/DNA_50nM\Pos2\original

# %%
# Call the function with the updated parameters
viz.plot_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="cy5",
    time_interval=time_interval,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False  # Set log_scale to True
)

# %%
# Call the function with the updated parameters
viz.plot_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="gfp",
    time_interval=time_interval,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False  # Set log_scale to True
)

# %%
# Call the function with the updated parameters
viz.plot_average_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="gfp",
    time_interval=time_interval,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False  # Set log_scale to True
)

# %%
viz.process_all_conditions_and_subconditions(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="cy5",
    time_interval=time_interval,  # Adjust as needed
    skip_frames=skip_frames,
    vmax=None,  # Adjust as needed
    frame_rate=frame_rate,  # Adjust as needed
    min_frame=0,
    max_frame=max_frame,
)
# Out:
# Video saved to ../../data/031124-k401-100nM_50nM/microtubules/single_movies_cy5\DNA_100nM_Pos0-cy5.avi
# Video saved to ../../data/031124-k401-100nM_50nM/microtubules/single_movies_cy5\DNA_100nM_Pos1-cy5.avi
# Video saved to ../../data/031124-k401-100nM_50nM/microtubules/single_movies_cy5\DNA_100nM_Pos2-cy5.avi
# Video saved to ../../data/031124-k401-100nM_50nM/microtubules/single_movies_cy5\DNA_50nM_Pos0-cy5.avi
# Video saved to ../../data/031124-k401-100nM_50nM/microtubules/single_movies_cy5\DNA_50nM_Pos1-cy5.avi
# Video saved to ../../data/031124-k401-100nM_50nM/microtubules/single_movies_cy5\DNA_50nM_Pos2-cy5.avi

# %%
# Example usage
data_path = "../../data/031124-k401-100nM_50nM/fluorescence/"
conditions = [
    'DNA_100nM',
    'DNA_50nM'
]
subconditions = ["Pos0", "Pos1", "Pos2"]
min_frame = 0
max_frame = None
time_interval=30
skip_frames=4
frame_rate=30

reorgTiffsToOriginal(data_path, conditions, subconditions)
# Out:
# Moved .tif files from ../../data/031124-k401-100nM_50nM/fluorescence/DNA_100nM\Pos0 to ../../data/031124-k401-100nM_50nM/fluorescence/DNA_100nM\Pos0\original
# Moved .tif files from ../../data/031124-k401-100nM_50nM/fluorescence/DNA_100nM\Pos1 to ../../data/031124-k401-100nM_50nM/fluorescence/DNA_100nM\Pos1\original
# Moved .tif files from ../../data/031124-k401-100nM_50nM/fluorescence/DNA_100nM\Pos2 to ../../data/031124-k401-100nM_50nM/fluorescence/DNA_100nM\Pos2\original
# Moved .tif files from ../../data/031124-k401-100nM_50nM/fluorescence/DNA_50nM\Pos0 to ../../data/031124-k401-100nM_50nM/fluorescence/DNA_50nM\Pos0\original
# Moved .tif files from ../../data/031124-k401-100nM_50nM/fluorescence/DNA_50nM\Pos1 to ../../data/031124-k401-100nM_50nM/fluorescence/DNA_50nM\Pos1\original
# Moved .tif files from ../../data/031124-k401-100nM_50nM/fluorescence/DNA_50nM\Pos2 to ../../data/031124-k401-100nM_50nM/fluorescence/DNA_50nM\Pos2\original

# %%
# Call the function with the updated parameters
viz.plot_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="cy5",
    time_interval=time_interval,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False  # Set log_scale to True
)

# %%
# Call the function with the updated parameters
viz.plot_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="gfp",
    time_interval=time_interval,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False  # Set log_scale to True
)

# %%
# Call the function with the updated parameters
viz.plot_average_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="gfp",
    time_interval=time_interval,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False  # Set log_scale to True
)

# %%
viz.process_all_conditions_and_subconditions(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="gfp",
    time_interval=time_interval,  # Adjust as needed
    skip_frames=skip_frames,
    vmax=0.02,  # Adjust as needed
    frame_rate=frame_rate,  # Adjust as needed
    min_frame=0,
    max_frame=max_frame,
)
# Out:
# Video saved to ../../data/031124-k401-100nM_50nM/fluorescence/single_movies_gfp\DNA_100nM_Pos0-gfp.avi
# Video saved to ../../data/031124-k401-100nM_50nM/fluorescence/single_movies_gfp\DNA_100nM_Pos1-gfp.avi
# Video saved to ../../data/031124-k401-100nM_50nM/fluorescence/single_movies_gfp\DNA_100nM_Pos2-gfp.avi
# Video saved to ../../data/031124-k401-100nM_50nM/fluorescence/single_movies_gfp\DNA_50nM_Pos0-gfp.avi
# Video saved to ../../data/031124-k401-100nM_50nM/fluorescence/single_movies_gfp\DNA_50nM_Pos1-gfp.avi
# Video saved to ../../data/031124-k401-100nM_50nM/fluorescence/single_movies_gfp\DNA_50nM_Pos2-gfp.avi

# %%
viz.grid_heatmaps(data_path, conditions, subconditions, "gfp")

# %%
viz.create_movies_grid(data_path, 'gfp', frame_rate)
# Out:
# Video saved to ../../data/031124-k401-100nM_50nM/fluorescence/grid-gfp.avi
