# %%
## Import relevant libraries
import sys
import os
import shutil
from natsort import natsorted  # For natural sorting
sys.path.append('../../activedrops')

## Including ourselves
import quadrop as qd
qd.set_plotting_style()

import glob
import imageio
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data_path = "../../data/100223-kva-kif-expression-nobeads/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])[::-1]

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])


# qd.reorgTiffsToOriginal(data_path, conditions, subconditions)

# %%
# channel info
channel = "gfp"
min_frame = 0
max_frame = None
skip_frames=32
frame_rate=30
time_intervals = [60] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True
)

# %%
data_path = "../../data/040624-K401_titration-30C/pos0-7_standards-KVA_titration_2/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])[::-1]

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])


# qd.reorgTiffsToOriginal(data_path, conditions, subconditions)

# %%
# channel info
channel = "gfp"
min_frame = 0
max_frame = None
skip_frames=32
frame_rate=30
time_intervals = [180] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True
)

# %%
data_path = "../../data/040528-kif3_titration-30C/80nM-40nM-20nM-10nM/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])[::-1]

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])


# qd.reorgTiffsToOriginal(data_path, conditions, subconditions)

# %%
# channel info
channel = "gfp"
min_frame = 0
max_frame = None
skip_frames=32
frame_rate=30
time_intervals = [60] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True
)

# %%
data_path = "../../data/032524-kva-kif-titrations-37C/4ultxtl-1ulDNA-1MT-1ulbuffer_1/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])[::-1]

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])


# qd.reorgTiffsToOriginal(data_path, conditions, subconditions)

# %%
# channel info
channel = "gfp"
min_frame = 0
max_frame = None
skip_frames=32
frame_rate=30
time_intervals = [60] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True
)

# %%
data_path = "../../data/032424-addmts_after_expression/kva-kif-adpa-60minincubation_2/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])[::-1]

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])


# qd.reorgTiffsToOriginal(data_path, conditions, subconditions)

# %%
# channel info
channel = "gfp"
min_frame = 0
max_frame = None
skip_frames=32
frame_rate=30
time_intervals = [60] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True
)

# %%
## Import relevant libraries
import sys
import os
import shutil
from natsort import natsorted  # For natural sorting
sys.path.append('../../activedrops')

## Including ourselves
import quadrop as qd
qd.set_plotting_style()

import glob
import imageio
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data_path = "../../data/020524-kif3-stirring/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])[::-1]

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])

conditions, subconditions

# qd.reorgTiffsToOriginal(data_path, conditions, subconditions)
# Out:
# (['DNA80nM_NoMT', 'DNA80nM_MT', 'DNA40nM_NoMT', 'DNA40nM_MT'],
#  ['Pos0', 'Pos1', 'Pos2'])

# %%
# channel info
channel = "gfp"
min_frame = 0
max_frame = None
skip_frames=32
frame_rate=30
time_intervals = [60] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True
)

# %%
data_path = "../../data/020524-kif3_repicetest/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])[::-1]

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])

conditions, subconditions

# qd.reorgTiffsToOriginal(data_path, conditions, subconditions)

# %%
# channel info
channel = "gfp"
min_frame = 0
max_frame = None
skip_frames=8
frame_rate=30
time_intervals = [60] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159 + 0.00018,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True
)

# %%
data_path = "../../data/031124-k401-100nM_50nM/exp-phase-piv_1/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])[::-1]

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])

conditions, subconditions

# qd.reorgTiffsToOriginal(data_path, conditions, subconditions)
# Out:
# (['K401_100nM-noMTs',
#   'K401_100nM-beads',
#   'K401_50nM-noMTs',
#   'K401_50nM-beads',
#   'K401_50nM-MTs',
#   'K401'],
#  ['Pos0', 'Pos1', 'Pos2'])

# %%
conditions = [condition for condition in conditions if "beads" not in condition]
conditions
# Out:
# ['K401_100nM-noMTs', 'K401_50nM-noMTs', 'K401_50nM-MTs', 'K401']

# %%
conditions = conditions[-1:]

# %%
# channel info
channel = "gfp"
min_frame = 0
max_frame = None
skip_frames=8
frame_rate=30
time_intervals = [300] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159+0.0006,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True
)

# %%
data_path = "../../data/031324-KIF3-g6p_TITRATION/20uM_MT-40nM_DNA-g6p-30sint_1/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])[::]

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])

conditions, subconditions

# qd.reorgTiffsToOriginal(data_path, conditions, subconditions)

# %%
# channel info
channel = "gfp"
min_frame = 0
max_frame = None
skip_frames=32
frame_rate=30
time_intervals = [30] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True
)

# %%
data_path = "../../data/093023-kva-kif-No_MT/2posKVA-2posKif3-3min_int_3/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])[::]

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])


conditions, subconditions

# qd.reorgTiffsToOriginal(data_path, conditions, subconditions)
# Out:
# (['K401', 'Kif3'], ['Pos0', 'Pos1', 'Pos2'])

# %%
# channel info
channel = "gfp"
min_frame = 0
max_frame = None
skip_frames=8
frame_rate=30
time_intervals = [180] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159-0.0008,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True
)

# %%
data_path = "../../data/20uM_MT-40nM_DNA-ATP-30sint_1/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])[::]

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])

conditions, subconditions

qd.reorgTiffsToOriginal(data_path, conditions, subconditions)

# %%
# channel info
channel = "gfp"
min_frame = 0
max_frame = None
skip_frames=32
frame_rate=30
time_intervals = [30] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True
)

# %%
data_path = "../../data/Kif3_MTs_titration/4ultxtl-2ulDNA150ngul-1MT_2/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])[::]

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])

conditions, subconditions

# qd.reorgTiffsToOriginal(data_path, conditions, subconditions)

# %%
# channel info
channel = "gfp"
min_frame = 0
max_frame = None
skip_frames=32
frame_rate=30
time_intervals = [60] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159+0.0002,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True
)

# %%
data_path = "../../data/kif3_phases/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])[::]

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])

conditions, subconditions

qd.reorgTiffsToOriginal(data_path, conditions, subconditions)

# %%
# channel info
channel = "gfp"
min_frame = 0
max_frame = None
skip_frames=32
frame_rate=30
time_intervals = [30] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159-0.0007,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=False
)

# %%
data_path = "../../data/Kif3_pH/5p4-6p4-7p4_1/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])[::]

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])

conditions, subconditions

qd.reorgTiffsToOriginal(data_path, conditions, subconditions)

# %%
# channel info
channel = "gfp"
min_frame = 2
max_frame = None
skip_frames=32
frame_rate=30
time_intervals = [30] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159+0.0002,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True
)

# %%
data_path = "../../data/032424-k401-kif3-heated/4ultxtl-0p5ulDNA-1p5M2B-1p5MT_1/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])[::]

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])

conditions, subconditions

qd.reorgTiffsToOriginal(data_path, conditions, subconditions)
# Out:
# Moved .tif files from ../../data/032424-k401-kif3-heated/4ultxtl-0p5ulDNA-1p5M2B-1p5MT_1/k401\Pos0 to ../../data/032424-k401-kif3-heated/4ultxtl-0p5ulDNA-1p5M2B-1p5MT_1/k401\Pos0\original
# Moved .tif files from ../../data/032424-k401-kif3-heated/4ultxtl-0p5ulDNA-1p5M2B-1p5MT_1/k401\Pos1 to ../../data/032424-k401-kif3-heated/4ultxtl-0p5ulDNA-1p5M2B-1p5MT_1/k401\Pos1\original
# Moved .tif files from ../../data/032424-k401-kif3-heated/4ultxtl-0p5ulDNA-1p5M2B-1p5MT_1/kif3\Pos0 to ../../data/032424-k401-kif3-heated/4ultxtl-0p5ulDNA-1p5M2B-1p5MT_1/kif3\Pos0\original
# Moved .tif files from ../../data/032424-k401-kif3-heated/4ultxtl-0p5ulDNA-1p5M2B-1p5MT_1/kif3\Pos1 to ../../data/032424-k401-kif3-heated/4ultxtl-0p5ulDNA-1p5M2B-1p5MT_1/kif3\Pos1\original

# %%
# channel info
channel = "gfp"
min_frame = 24
max_frame = None
skip_frames=8
frame_rate=30
time_intervals = [30] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159+0.00095,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True
)
