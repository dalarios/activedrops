# %%
## Import relevant libraries
import sys
import os
import shutil
from natsort import natsorted  # For natural sorting
sys.path.append('../../activedrops')

## Including ourselves
import quadrop as qd
qd.set_plotting_style()

import glob
import imageio
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data_path = "../../data/041524-9motors-33C/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])

conditions
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 data_path = "../../data/041524-9motors-33C/"
#       3 # let's declare the variable "conditions" to the sorted list of subdirectories from data_path
# ----> 4 conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])
#       6 # let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
#       7 subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/041524-9motors-33C/'

# %%
conditions = ['k401', 'kif3', 'kif5']

# %%
qd.reorgTiffsToOriginal(data_path, conditions, subconditions)

# %%
# channel info
channel = "gfp"
min_frame = 0
max_frame = -800
skip_frames=64
time_intervals = [60] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True,
    legend_loc='upper left'
)

# %%
# frame info
min_frame = 0
max_frame = None
skip_frames=16
time_intervals = [60] * len(conditions) 
frame_rate=15


# channel info
channel = "cy5"
vmax = 0.5

qd.single_fluorescence_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel, 
    time_intervals, 
    min_frame, 
    max_frame, 
    vmax, 
    skip_frames, 
    frame_rate)
# Out:
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/CaFa_Pos8-cy5.avi
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/DiPu_Pos8-cy5.avi
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/Didi_Pos8-cy5.avi
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/NCD_Pos8-cy5.avi
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/NaFo_Pos8-cy5.avi
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/PaBi_Pos8-cy5.avi
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/PoVi_Pos8-cy5.avi
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/SteCoe_Pos8-cy5.avi
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/SteCoe4_Pos8-cy5.avi
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/StyLe_Pos8-cy5.avi
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/ThTr_Pos8-cy5.avi
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/TiLa_Pos8-cy5.avi
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/TrBr_Pos8-cy5.avi
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/TrVa_Pos8-cy5.avi
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/Unc116_Pos8-cy5.avi
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/k401_Pos8-cy5.avi
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/kif3_Pos8-cy5.avi
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/kif5_Pos8-cy5.avi
# Video saved to ../../data/041524-9motors-33C/single_movies_cy5/negative_Pos8-cy5.avi

# %%
# channel info
time_intervals = [60] * len(conditions) 
frame_rate=60

channel = "gfp"
vmax = 80

qd.single_fluorescence_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel, 
    time_intervals, 
    min_frame, 
    max_frame, 
    vmax, 
    skip_frames, 
    frame_rate,
    line_slope=0.00042, 
    line_intercept=0.00159,
    )

# %%
data_path = "../../data/motor_screening2/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])[:-2]

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])
conditions
# Out:
# ['AdPa', 'HeAl', 'NaGr', 'ThTr']

# %%
qd.reorgTiffsToOriginal(data_path, conditions, subconditions)
# Out:
# Moved .tif files from ../../data/motor_screening2/AdPa/Pos0 to ../../data/motor_screening2/AdPa/Pos0/original
# Moved .tif files from ../../data/motor_screening2/HeAl/Pos0 to ../../data/motor_screening2/HeAl/Pos0/original
# Moved .tif files from ../../data/motor_screening2/NaGr/Pos0 to ../../data/motor_screening2/NaGr/Pos0/original
# Moved .tif files from ../../data/motor_screening2/ThTr/Pos0 to ../../data/motor_screening2/ThTr/Pos0/original

# %%
# channel info
channel = "gfp"
min_frame = 0
max_frame = None
skip_frames=64
time_intervals = [180] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True
)

# %%
# frame info
min_frame = 0
max_frame = None
skip_frames=8
time_intervals = [180] * len(conditions) 
frame_rate=10


# channel info
channel = "cy5"
vmax = 0.5

qd.single_fluorescence_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel, 
    time_intervals, 
    min_frame, 
    max_frame, 
    vmax, 
    skip_frames, 
    frame_rate)
# Out:
# Video saved to ../../data/motor_screening2/single_movies_cy5/AdPa_Pos0-cy5.avi
# Video saved to ../../data/motor_screening2/single_movies_cy5/HeAl_Pos0-cy5.avi
# Video saved to ../../data/motor_screening2/single_movies_cy5/NaGr_Pos0-cy5.avi
# Video saved to ../../data/motor_screening2/single_movies_cy5/ThTr_Pos0-cy5.avi

# %%
# channel info
time_intervals = [180] * len(conditions) 
frame_rate=15

channel = "gfp"
vmax = 80

qd.single_fluorescence_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel, 
    time_intervals, 
    min_frame, 
    max_frame, 
    vmax, 
    skip_frames, 
    frame_rate,
    line_slope=0.00042, 
    line_intercept=0.00159,
    )

# %%
data_path = "../../data/temperatures/"

# let's declare the variable "conditions" to the sorted list of subdirectories from data_path
conditions = natsorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])

# let's declare the variable "subconditions" to the sorted list of subdirectories from the first condition
subconditions = natsorted([f for f in os.listdir(os.path.join(data_path, conditions[0])) if os.path.isdir(os.path.join(data_path, conditions[0], f))])
conditions

# %%
qd.reorgTiffsToOriginal(data_path, conditions, subconditions)

# %%
# channel info
channel = "gfp"
min_frame = 0
max_frame = None
skip_frames=64
time_intervals = [60] * len(conditions)

# Call the function with the updated parameters
qd.plot_fluorescence(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel=channel,
    time_intervals=[180, 60, 60, 60, 180, 60],  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    line_slope=0.00042, 
    line_intercept=0.00159,
    log_scale=False,  # Set log_scale to True
    timescale="h",
    averaged=True,
    legend_loc='upper left'
)

# %%
# frame info
min_frame = 0
max_frame = None
skip_frames=16
time_intervals = [180, 60, 60, 60, 180, 60]
frame_rate=15


# channel info
channel = "cy5"
vmax = 0.07

qd.single_fluorescence_movies(
    data_path, 
    conditions[2:3], 
    subconditions, 
    channel, 
    time_intervals[2:3], 
    min_frame, 
    max_frame, 
    vmax, 
    skip_frames, 
    frame_rate)

# %%
channel = "gfp"
vmax = 40

qd.single_fluorescence_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel, 
    time_intervals, 
    min_frame, 
    max_frame, 
    vmax, 
    skip_frames, 
    frame_rate,
    line_slope=0.00042, 
    line_intercept=0.00159,
    )
