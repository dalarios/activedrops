# %%
## Import relevant libraries
import sys
sys.path.append('../../activedrops')

## Including ourselves
import quadrop as qd
qd.set_plotting_style()

# %%
# Example usage
data_path = "../../data/20MT-40DNA-ATP_titration/"
conditions = ["0mM-ATP", "3mM-ATP", "7mM-ATP"]
subconditions = ["rep1"]


# frame info
min_frame = 0
max_frame = None
skip_frames=4
frame_rate=30
time_intervals = [30, 30, 30]

# channel info
channel = "cy5"
vmax = 0.1

# %%
# Call the function with the updated parameters
qd.plot_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="cy5",
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False,  # Set log_scale to True
    timescale="min"
)

# %%
# Call the function with the updated parameters
qd.plot_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="gfp",
    time_intervals=time_intervals,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False,  # Set log_scale to True
    timescale="min"
)

# %%
# Example usage
data_path = "../../data/20MT-40DNA-ATP_titration/"
conditions = ["0mM-ATP", "3mM-ATP", "7mM-ATP"]
subconditions = ["rep1"]


# frame info
min_frame = 0
max_frame = None
skip_frames=4
frame_rate=30
time_intervals = [30, 30, 30]

# channel info
channel = "cy5"
vmax = 0.5

qd.single_fluorescence_movies(data_path, conditions, subconditions, channel, time_intervals, min_frame, max_frame, vmax, skip_frames, frame_rate)
# Out:
# Video saved to ../../data/20MT-40DNA-ATP_titration/single_movies_cy5/0mM-ATP_rep1-cy5.avi
# Video saved to ../../data/20MT-40DNA-ATP_titration/single_movies_cy5/3mM-ATP_rep1-cy5.avi
# Video saved to ../../data/20MT-40DNA-ATP_titration/single_movies_cy5/7mM-ATP_rep1-cy5.avi

# %%
# Example usage
data_path = "../../data/20MT-40DNA-ATP_titration/"
conditions = ["0mM-ATP", "3mM-ATP", "7mM-ATP"]
subconditions = ["rep1"]


# frame info
min_frame = 0
max_frame = None
skip_frames=4
frame_rate=30
time_intervals = [30, 30, 30]

# channel info
channel = "gfp"
vmax = 0.01

qd.single_fluorescence_movies(data_path, conditions, subconditions, channel, time_intervals, min_frame, max_frame, vmax, skip_frames, frame_rate)
# Out:
# Video saved to ../../data/20MT-40DNA-ATP_titration/single_movies_gfp/0mM-ATP_rep1-gfp.avi
# Video saved to ../../data/20MT-40DNA-ATP_titration/single_movies_gfp/3mM-ATP_rep1-gfp.avi
# Video saved to ../../data/20MT-40DNA-ATP_titration/single_movies_gfp/7mM-ATP_rep1-gfp.avi

# %%
qd.grid_heatmaps(data_path, conditions, subconditions, "cy5", frame_rate=frame_rate, figsize=(12,8))
