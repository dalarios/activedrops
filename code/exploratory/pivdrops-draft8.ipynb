# %% [markdown]
# Here I tried Kif3 ActiveDROP with 500 and 1100 ng/ul linear DNA, two reps each. Let's first look at a single rep cutting every other or every fourth frame, just to see if we get useful vectors with longer time intervals per frame. The movies were originally taken at 6 seconds per frame.

# %%
## Import relevant libraries
import sys
sys.path.append('../../activedrops')

## Including ourselves
import pivdrops
pivdrops.set_plotting_style()

# %%
data_path = "../../data/012424-kif3-2concentrations-expression_motion/"
condition1 = "500ngul"
subcondition1 = "rep1"
subcondition2 = "rep1-half"
subcondition3 = "rep1-quarter"


min_frame = 0
max_frame = None


# rep1_ts, rep1_pivot = pivdrops.process_piv_data(data_path, condition1, subcondition1, min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# rep2_ts, rep2_pivot = pivdrops.process_piv_data(data_path, condition1, subcondition2, min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
rep3_ts, rep3_pivot = pivdrops.process_piv_data(data_path, condition1, subcondition3, min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)

# %%
time_intervals = [6, 12, 24]

features_pca = [
    # "data type [-]_mean", 
    # "vorticity [1/s]_mean",	
    # "velocity magnitude [um/s]", 
    # "divergence [1/s]_mean", 
    # "dcev [1]_mean", 
    # "shear [1/s]_mean", 
    # "strain [1/s]_mean", 
    # "vector direction [degrees]_mean", 
    "correlation length [um]", 
    "power [W]_mean",
    "work [J]", 
    ]

# pivdrops.plot_features([data_path, data_path, data_path], [condition, condition, condition], [subcondition1, subcondition2, subcondition3], features_pca, time_intervals=time_intervals, sigma=1)
pivdrops.plot_features([data_path, data_path, data_path], [condition1, condition1, condition1], [subcondition1, subcondition2, subcondition3], features_pca, time_intervals=time_intervals, sigma=1)

# %% [markdown]
# Just seeing the vector fields is enough to tell that longer time intervals don't work well. The produced plots are kinda similar but vectors are not convincing, so let's stick to 6 seconds/frame. Now let's look at all of the reps with this original time interval.

# %%
## Import relevant libraries
import sys
sys.path.append('../../activedrops')

## Including ourselves
import pivdrops
pivdrops.set_plotting_style()

# %%
data_path = "../../data/012424-kif3-2concentrations-expression_motion/"
condition1 = "500ngul"
condition2 = "1100ngul"
subcondition1 = "rep1"
subcondition2 = "rep2"


min_frame = 0
max_frame = None


rep1_ts, a = pivdrops.process_piv_data(data_path, condition1, subcondition1, min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
rep2_ts, b = pivdrops.process_piv_data(data_path, condition1, subcondition2, min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)

rep3_ts, c = pivdrops.process_piv_data(data_path, condition2, subcondition1, min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
rep3_ts, d = pivdrops.process_piv_data(data_path, condition2, subcondition2, min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)

# %%
features_pca = [
    # "data type [-]_mean", 
    # "vorticity [1/s]_mean",	
    "velocity magnitude [um/s]", 
    # "divergence [1/s]_mean", 
    # "dcev [1]_mean", 
    # "shear [1/s]_mean", 
    # "strain [1/s]_mean", 
    # "vector direction [degrees]_mean", 
    "correlation length [um]", 
    "power [W]_mean",
    "work [J]", 
    ]

pivdrops.plot_features(
    [data_path, data_path, data_path, data_path], 
    [condition1, condition1, condition2, condition2], 
    [subcondition1, subcondition2, subcondition1, subcondition2], 
    features_pca, time_intervals=[6, 6, 6, 6], 
    sigma=1,  
    min_frame=0, 
    max_frame=None,
    # trajectories=True,
    )

# %%
# pivdrops.convert_images(data_path, condition1, subcondition1, max_frame=max_frame, brightness_factor=1, contrast_factor=1)
# pivdrops.convert_images(data_path, condition1, subcondition2, max_frame=max_frame, brightness_factor=1, contrast_factor=1)

# pivdrops.convert_images(data_path, condition2, subcondition1, max_frame=max_frame, brightness_factor=1, contrast_factor=1)
# pivdrops.convert_images(data_path, condition2, subcondition2, max_frame=max_frame, brightness_factor=1, contrast_factor=1)



v = 10E-6
velocity_limits = (0, v)
other_limits = (-0.15, 0.15)


# velocity_limits = (None, None)
# other_limits = (None, None)

feature_limits = {
    'u [m/s]': (-v, v), 
    'v [m/s]': (-v, v), 
    'data type [-]': (None, None),
    'velocity magnitude [m/s]': velocity_limits,
    'vorticity [1/s]': other_limits,
    'divergence [1/s]': other_limits,
    'dcev [1]': (0, 250),
    'shear [1/s]': other_limits,
    'strain [1/s]': other_limits,
    'vector direction [degrees]': (-180, 180),
}

min_frame = 100
max_frame = 120
 
pivdrops.piv_heatmap(a.iloc[min_frame:max_frame,:], data_path, condition1, subcondition1, feature_limits, time_interval=6)
pivdrops.piv_heatmap(b.iloc[min_frame:max_frame,:], data_path, condition1, subcondition2, feature_limits, time_interval=6)
pivdrops.piv_heatmap(c.iloc[min_frame:max_frame,:], data_path, condition2, subcondition1, feature_limits, time_interval=6)
pivdrops.piv_heatmap(d.iloc[min_frame:max_frame,:], data_path, condition2, subcondition2, feature_limits, time_interval=6)


pivdrops.create_heatmap_movies(data_path, condition1, subcondition1, feature_limits)
pivdrops.create_heatmap_movies(data_path, condition1, subcondition2, feature_limits)
pivdrops.create_heatmap_movies(data_path, condition2, subcondition1, feature_limits)
pivdrops.create_heatmap_movies(data_path, condition2, subcondition2, feature_limits)

# %% [markdown]
# Let's compare with kbio

# %%
## Import relevant libraries
import sys
sys.path.append('../../activedrops')

## Including ourselves
import pivdrops
pivdrops.set_plotting_style()


data_path = "../../data/01-k401-biotin_strep/"
condition1 = "125nM"
condition2 = "250nM"
condition3 = "500nM"
subcondition1 = "2ul"


min_frame = 0
max_frame = None


rep1_ts, a = pivdrops.process_piv_data(data_path, condition1, subcondition1, min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
rep2_ts, b = pivdrops.process_piv_data(data_path, condition2, subcondition1, min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
rep3_ts, c = pivdrops.process_piv_data(data_path, condition3, subcondition1, min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)

# %%
features_pca = [
    # "data type [-]_mean", 
    # "vorticity [1/s]_mean",	
    # "velocity magnitude [um/s]", 
    # "divergence [1/s]_mean", 
    # "dcev [1]_mean", 
    # "shear [1/s]_mean", 
    # "strain [1/s]_mean", 
    # "vector direction [degrees]_mean", 
    "correlation length [um]", 
    "power [W]_mean",
    "work [J]", 
    ]

pivdrops.plot_features(
    [data_path, data_path, data_path, data_path], 
    [condition1, condition2, condition3], 
    [subcondition1, subcondition1, subcondition1], 
    features_pca, time_intervals=[3, 3, 3], 
    sigma=1,  
    min_frame=50, 
    max_frame=600,
    # trajectories=True,
    )

# %%
data_path = "../../data/01-k401-biotin_strep/"
condition1 = "125nM"
condition2 = "250nM"
condition3 = "500nM"
subcondition1 = "2ul"


data_patha = "../../data/012424-kif3-2concentrations-expression_motion/"
condition1a = "500ngul"
condition2a = "1100ngul"
subcondition1a = "rep1"
subcondition2a = "rep2"



features_pca = [
    # "data type [-]_mean", 
    # "vorticity [1/s]_mean",	
    # "velocity magnitude [um/s]", 
    # "divergence [1/s]_mean", 
    # "dcev [1]_mean", 
    # "shear [1/s]_mean", 
    # "strain [1/s]_mean", 
    # "vector direction [degrees]_mean", 
    "correlation length [um]", 
    "power [W]_mean",
    "work [J]", 
    ]



pivdrops.plot_features(
    [data_path, data_patha, data_patha], 
    [condition3, condition1a, condition2a], 
    [subcondition1, subcondition1a, subcondition1a], 
    features_pca, time_intervals=[3, 6, 6], 
    sigma=1,  
    min_frame=0, 
    max_frame=None,
    # trajectories=True,
    )

# %% [markdown]
# Now fig 2

# %%
## Import relevant libraries
import sys
sys.path.append('../../activedrops')

## Including ourselves
import pivdrops
pivdrops.set_plotting_style()


data_path = "../../data/02-ActiveDROPSfig2-K401_Kif3/"
condition1 = "k401"
condition2 = "kif3"
subcondition1 = "rep1"


min_frame = 0
max_frame = None


rep1_ts, a = pivdrops.process_piv_data(data_path, condition1, subcondition1, min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
rep2_ts, b = pivdrops.process_piv_data(data_path, condition2, subcondition1, min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)

# %%
features_pca = [
    # "data type [-]_mean", 
    # "vorticity [1/s]_mean",	
    # "velocity magnitude [um/s]", 
    # "divergence [1/s]_mean", 
    # "dcev [1]_mean", 
    # "shear [1/s]_mean", 
    # "strain [1/s]_mean", 
    # "vector direction [degrees]_mean", 
    "correlation length [um]", 
    "power [W]_mean",
    "work [J]", 
    ]

pivdrops.plot_features(
    [data_path, data_path], 
    [condition1, condition2], 
    [subcondition1, subcondition1], 
    features_pca, time_intervals=[3, 3], 
    sigma=1,  
    min_frame=50, 
    max_frame=600,
    # trajectories=True,
    )

# %%
data_path = "../../data/01-k401-biotin_strep/"
condition1 = "125nM"
condition2 = "250nM"
condition3 = "500nM"
subcondition1 = "2ul"


data_patha = "../../data/012424-kif3-2concentrations-expression_motion/"
condition1a = "500ngul"
condition2a = "1100ngul"
subcondition1a = "rep1"
subcondition2a = "rep2"


data_pathb = "../../data/02-ActiveDROPSfig2-K401_Kif3/"
condition1b = "k401"
condition2b = "kif3"
subcondition1b = "rep1"


features_pca = [
    # "data type [-]_mean", 
    # "vorticity [1/s]_mean",	
    # "velocity magnitude [um/s]", 
    # "divergence [1/s]_mean", 
    # "dcev [1]_mean", 
    # "shear [1/s]_mean", 
    # "strain [1/s]_mean", 
    # "vector direction [degrees]_mean", 
    "correlation length [um]", 
    # "power [W]_mean",
    "work [J]", 
    ]



pivdrops.plot_features(
    [data_path, data_patha, data_patha, data_pathb, data_pathb], 
    [condition3, condition1a, condition2a, condition1b, condition2b], 
    [subcondition1, subcondition1a, subcondition1a, subcondition1b, subcondition1b], 
    features_pca, time_intervals=[3, 6, 6, 3, 3], 
    sigma=1,  
    min_frame=0, 
    max_frame=None,
    # trajectories=True,
    )
