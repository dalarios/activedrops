# %%
## Import relevant libraries
import sys
import glob

sys.path.append('../../py_files/')
import quadrop2 as qd

qd.set_plotting_style()

# %% [markdown]
# ### Data pre-procesing

# %%
# Example usage
base_dir = "../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/072025-ThTr-piv-beads/"
qd.consolidate_images(base_dir)
# Out:
# Consolidation appears to be already done. Directory '../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/072025-ThTr-piv-beads/2p5ulTMB-1ulDNA_' already exists with subfolders.

# %%
# Example usage
data_path = "../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/072025-ThTr-piv-beads/2p5ulTMB-1ulDNA_/"

calibration_curve_paths = sorted(glob.glob("../../../../Thomson Lab Dropbox/David Larios/activedrops/calibration_curve/***ugml.tif"))


conditions_dict = {
    "ThTr_85nM": "Pos0",
    "ThTr_8nM": "Pos1",

}


# Organize PosX folders into condition folders
qd.organize_conditions(data_path, conditions_dict)

# Now run the existing functions to reorganize the tiffs and rename the folders
conditions, subconditions = qd.prepare_conditions(data_path)
# time_interval_list = [180] * len(conditions)  # time intervals in seconds between frames for each condition

subconditions = ['Rep1']
print("Conditions:", conditions)
print("Subconditions:", subconditions)
# Out:
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/072025-ThTr-piv-beads/2p5ulTMB-1ulDNA_/Pos0 does not exist. Skipping.
# Warning: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/072025-ThTr-piv-beads/2p5ulTMB-1ulDNA_/Pos1 does not exist. Skipping.
# Conditions: ['ThTr_8nM', 'ThTr_85nM']
# Subconditions: ['Rep1']

# %%
qd.reorgTiffsToOriginal(data_path, conditions, subconditions)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 qd.reorgTiffsToOriginal(data_path, conditions, subconditions)
#
# File ~/git/activedrops/code/exploratory/../../py_files/quadrop2.py:306, in reorgTiffsToOriginal(data_path, conditions, subconditions)
#     304 # Rename the actual subconditions to match the subconditions in your list
#     305 for i, actual_subcondition in enumerate(actual_subconditions):
# --> 306     os.rename(os.path.join(data_path, condition, actual_subcondition), os.path.join(data_path, condition, matched_subconditions[i]))
#     308 for subcondition in matched_subconditions:
#     309     # Construct the path to the subcondition directory
#     310     subcondition_path = os.path.join(data_path, condition, subcondition)
#
# IndexError: list index out of range

# %% [markdown]
# ### Generate movies

# %%
# Call the function
qd.fluorescence_heatmap(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    time_interval_list=[15, 15], 
    vmax=14, 
    skip_frames=10, 
    calibration_curve_paths=calibration_curve_paths, 
    show_scalebar=False,
    )

# %%
# Example usage
qd.create_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    frame_rate=60,
    skip_frames=1
    )

# %%
conditions[::-1]

# %%
len(conditions)

# %%
qd.create_combined_heatmap_movie_custom_grid(
    data_path, 
    conditions, 
    subconditions, 
    channel='cy5', 
    grid_rows=4, 
    grid_cols=8, 
    frame_rate=15,
    batch_size=50
    )

# %%
# Call the function
qd.fluorescence_heatmap(
    data_path, 
    conditions[:], 
    subconditions, 
    channel='DAPI', 
    time_interval_list=[15, 15], 
    vmax=500, 
    skip_frames=40, 
    calibration_curve_paths=calibration_curve_paths, 
    show_scalebar=True,
    )

# %%
# Example usage
qd.create_movies(
    data_path, 
    conditions, 
    subconditions, 
    channel='DAPI', 
    frame_rate=15,
    skip_frames=1
    )

# %%
qd.create_combined_heatmap_movie_custom_grid(
    data_path, 
    conditions, 
    subconditions, 
    channel='GFP', 
    grid_rows=4, 
    grid_cols=8,       
    frame_rate=4,
    batch_size=50
    )

# %%
# qd.delete_temporary_image_directories(data_path, conditions, subconditions)

# %% [markdown]
# ### Fluorescence Quantification

# %%
conditions

# %%
# Example usage
# mw_kda_list = [44.95] * len(conditions)
droplet_volume_list = [2] * len(conditions)
# protein_lengths_list = [401] * len(conditions) # last one is negative

qd.quantify_tiffiles(
    data_path, 
    conditions, 
    subconditions, 
    calibration_curve_paths, 
    droplet_volume_list, 
    [300,300], # gfp pics taken with higher interval to avovid photobleaching
    skip_frames=1,

)
# Out:
# Calculating intensities for ThTr_8nM - Rep1: 100%|██████████| 521/521 [00:03<00:00, 156.77it/s]
# Calculating intensities for ThTr_85nM - Rep1: 100%|██████████| 521/521 [00:03<00:00, 155.11it/s]
# ('../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/072025-ThTr-piv-beads/2p5ulTMB-1ulDNA_/output_data/combined_expression.csv',
#  '../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/072025-ThTr-piv-beads/2p5ulTMB-1ulDNA_/output_data/mean_expression.csv')

# %% [markdown]
# ### PIV pre-processing

# %%
qd.split_tiffs(data_path, conditions, subconditions, channel='cy5', file_interval=1)

# %%
qd.split_tiffs(data_path, conditions, subconditions, channel='dapi', file_interval=1)

# %% [markdown]
# ### PIV

# %%
# Define feature limits and other parameters
v = 2E-7
velocity_limits = (0, v)
other_limits = (-0.0005, 0.0005)
skip_frames = 1 ### CHANGE THIS TO SKIP FRAMES


velocity_limits = (None, None)
other_limits = (None, None)


feature_limits = {
    # 'u [m/s]': (-v, v), 
    # 'v [m/s]': (-v, v), 
    # 'data type [-]': (None, None),
    'velocity magnitude [m/s]': velocity_limits,
    'vorticity [1/s]': other_limits,
    'divergence [1/s]': other_limits,
    # 'dcev [1]': (0, 250),
    'shear [1/s]': other_limits,
    'strain [1/s]': other_limits,
    'vector direction [degrees]': (-180, 180),
}


# Features for PCA and plotting
features_pca = [
    "vorticity [1/s]_mean",
    "velocity magnitude [um/s]",
    "distance [m]_mean",
    "divergence [1/s]_mean",
    "shear [1/s]_mean",
    "strain [1/s]_mean",
    "correlation length [um]", 
    "power [W]_mean",
    "work [J]",
]

# %%
conditions[:1]

# %%
time_interval_list = [15, 15]  # time intervals in seconds between frames for each condition


# Process PIV data
qd.process_piv_data(
    data_path, 
    conditions[:],    
    subconditions, 
    feature_limits, 
    time_interval_list, 
    min_frame=0, 
    max_frame=None, 
    skip_frames=1, 
    plot_autocorrelation=False, 
    frame_rate=1, 
    heatmaps=False
    )
# Out:
# Processing PIV data:   0%|          | 0/2 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data:  50%|█████     | 1/2 [02:42<02:42, 162.97s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing PIV data: 100%|██████████| 2/2 [04:49<00:00, 144.66s/it]

# %%
# Plot features and PCA
qd.plot_PIV_all(
    data_path, 
    conditions[:1],
    subconditions, 
    features_pca, 
    min_frame=0, 
    max_frame=None
    )

# %% [markdown]
# ### Expression + PIV

# %%
# Combine the data and save it to the "output_data" directory
qd.combine_averaged_dataframes(data_path, conditions[:], subconditions)
# Out:
# Conditions: 100%|██████████| 2/2 [00:00<00:00, 48.75it/s]
# Combined DataFrame saved to: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/072025-ThTr-piv-beads/2p5ulTMB-1ulDNA_/output_data/combined_PIV.csv

# %%
qd.merge_expression_piv_data(data_path)
# Out:
# Merged DataFrame saved to: ../../../../Thomson Lab Dropbox/David Larios/activedrops/ubuntu/072025-ThTr-piv-beads/2p5ulTMB-1ulDNA_/output_data/merged_expression_PIV.csv

# %%
# x_column = "time (h)"  # Example x-axis column
# y_column = "Protein Concentration_nM"  # Example y-axis column


# x_column = "Protein Concentration_nM"  # Example y-axis column
# y_column = "velocity magnitude [m/s]_mean"  # Example y-axis column

# x_column = "time (h)"  # Example x-axis column
# y_column = "velocity magnitude [m/s]_mean"  # Example y-axis column

# x_column = "time (h)"  # Example x-axis columns
# y_column = "power [W]_mean"  # Example y-axis column

# x_column = "time (h)"  # Example x-axis column
# y_column = "work [J]_mean"  # Example y-axis column

x_column = "time (h)"  # Example x-axis column
y_column = "distance [m]_mean"  # Example y-axis column


qd.plot_expression_piv(
    data_path,
    conditions,
    x_column, 
    y_column, 
    sigma_x=0.1, 
    sigma_y=10, 
    x_log=False, 
    y_log=True, 
    min_frame=0, 
    max_frame=None, 
    individual_plots=False
    )

# %%
# List of features for PCA
features_pca = [
    "vorticity [1/s]_mean",
    "velocity magnitude [m/s]_mean",
    "distance [m]_mean",
    "divergence [1/s]_mean",
    "shear [1/s]_mean",
    "strain [1/s]_mean",
    "correlation length [m]_mean", 
    "power [W]_mean",
    "work [J]_mean",
    'vector direction [degrees]_mean',
    "Protein Concentration_nM", 
    'time (min)'
]

# Run PCA and save plot (with all conditions and subconditions in the same plot)
qd.plot_pca_expression_piv(data_path, conditions=conditions, subconditions=subconditions, features=features_pca, sigma=1)

# %%
# Example usage
qd.delete_outputs(data_path, conditions, subconditions, output_dirs=None)
