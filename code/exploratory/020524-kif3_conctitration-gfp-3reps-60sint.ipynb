# %%
## Import relevant libraries
import sys
sys.path.append('../../activedrops')
import pivdrops
import viz
pivdrops.set_plotting_style()

# %%
# import os
# import shutil

# def reorgTiffsToOriginal(data_path, conditions, subconditions):
#     for condition in conditions:
#         for subcondition in subconditions:
#             # Construct the path to the subcondition directory
#             subcondition_path = os.path.join(data_path, condition, subcondition)
            
#             # Create the path for the "original" directory within the subcondition directory
#             original_dir_path = os.path.join(subcondition_path, "original")
            
#             # Always create the "original" directory
#             os.makedirs(original_dir_path)
            
#             # Iterate over all files in the subcondition directory
#             for filename in os.listdir(subcondition_path):
#                 # Check if the file is a .tif file
#                 if filename.endswith(".tif"):
#                     # Construct the full path to the file
#                     file_path = os.path.join(subcondition_path, filename)
                    
#                     # Construct the path to move the file to
#                     destination_path = os.path.join(original_dir_path, filename)
                    
#                     # Move the file to the "original" directory
#                     shutil.move(file_path, destination_path)
#             print(f"Moved .tif files from {subcondition_path} to {original_dir_path}")

# %%
# Example usage
data_path = "../../data/020524-kif3_conctitration-gfp-3reps-60sint/"
conditions = [
    'DNA1p25nM',
    'DNA1p25nM_MT20nM',
    'DNA2p5nM',
    'DNA2p5nM_MT20nM',
    'DNA5nM',
    'DNA5nM_MT20nM',
    'DNA10nM',
    'DNA10nM_MT20nM',
    'DNA20nM',
    'DNA20nM_MT20nM',
    'DNA40nM',
    'DNA40nM_MT20nM'
]
subconditions = ["Pos0", "Pos1", "Pos2"]
min_frame = 0
max_frame = None
time_interval=30
skip_frames=4
frame_rate=30

# reorgTiffsToOriginal(data_path, conditions, subconditions)

# %%
# Call the function with the updated parameters
viz.plot_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="cy5",
    time_interval=time_interval,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False  # Set log_scale to True
)

# %%
# Call the function with the updated parameters
viz.plot_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="gfp",
    time_interval=time_interval,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False  # Set log_scale to True
)

# %%
# Example usage
data_path = "../../data/020524-kif3_conctitration-gfp-3reps-60sint/"

conditions = [
    'DNA1p25nM',
    'DNA2p5nM',
    'DNA5nM',
    'DNA10nM',
    'DNA20nM',
    'DNA40nM',
]

subconditions = ["Pos0", "Pos1", "Pos2"]

min_frame = 0
max_frame = None
time_interval = 30
skip_frames = 4

# Call the function with the updated parameters
viz.plot_average_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="gfp",
    time_interval=time_interval,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False  # Set log_scale to True
)

# %%
# Example usage
data_path = "../../data/020524-kif3_conctitration-gfp-3reps-60sint/"

conditions = [
    'DNA1p25nM_MT20nM',
    'DNA2p5nM_MT20nM',
    'DNA5nM_MT20nM',
    'DNA10nM_MT20nM',
    'DNA20nM_MT20nM',
    'DNA40nM_MT20nM'
]

subconditions = ["Pos0", "Pos1", "Pos2"]

min_frame = 0
max_frame = None
time_interval = 30
skip_frames = 4

# Call the function with the updated parameters
viz.plot_average_fluorescence_vs_time(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="gfp",
    time_interval=time_interval,  
    min_frame=min_frame,
    max_frame=max_frame,
    skip_frames=skip_frames,
    log_scale=False  # Set log_scale to True
)

# %%
viz.process_all_conditions_and_subconditions(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="cy5",
    time_interval=time_interval,  # Adjust as needed
    skip_frames=skip_frames,
    vmax=None,  # Adjust as needed
    frame_rate=frame_rate,  # Adjust as needed
    min_frame=0,
    max_frame=max_frame,
)

# %%
viz.process_all_conditions_and_subconditions(
    data_path=data_path,
    conditions=conditions,
    subconditions=subconditions,
    channel="gfp",
    time_interval=time_interval,  # Adjust as needed
    skip_frames=skip_frames,
    vmax=None,  # Adjust as needed
    frame_rate=frame_rate,  # Adjust as needed
    min_frame=0,
    max_frame=max_frame,
)

# %%
viz.grid_heatmaps(data_path, conditions, subconditions, "gfp")

# %%
viz.create_movies_grid(data_path, 'gfp', frame_rate)

# %%
# Example usage
data_path = "../../data/020524-kif3_conctitration-gfp-3reps-60sint/"

conditions = [
    'DNA1p25nM',
    'DNA1p25nM_MT20nM',
    'DNA2p5nM',
    'DNA2p5nM_MT20nM',
    'DNA5nM',
    'DNA5nM_MT20nM',
    'DNA10nM',
    'DNA10nM_MT20nM',
    'DNA20nM',
    'DNA20nM_MT20nM',
    'DNA40nM',
    'DNA40nM_MT20nM'
]

subconditions = ["Pos0", "Pos1", "Pos2"]

min_frame = 0
max_frame = None
time_interval = 30
skip_frames = 4

m11, p11 = pivdrops.process_piv_data(data_path, conditions[0], subconditions[0], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
m12, p12 = pivdrops.process_piv_data(data_path, conditions[0], subconditions[1], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
m13, p13 = pivdrops.process_piv_data(data_path, conditions[0], subconditions[2], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)

# m21, p21 = pivdrops.process_piv_data(data_path, conditions[1], subconditions[0], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m22, p22 = pivdrops.process_piv_data(data_path, conditions[1], subconditions[1], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m23, p23 = pivdrops.process_piv_data(data_path, conditions[1], subconditions[2], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)

# m31, p31 = pivdrops.process_piv_data(data_path, conditions[2], subconditions[0], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m32, p32 = pivdrops.process_piv_data(data_path, conditions[2], subconditions[1], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m33, p33 = pivdrops.process_piv_data(data_path, conditions[2], subconditions[2], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)

# m41, p41 = pivdrops.process_piv_data(data_path, conditions[3], subconditions[0], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m42, p42 = pivdrops.process_piv_data(data_path, conditions[3], subconditions[1], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m43, p43 = pivdrops.process_piv_data(data_path, conditions[3], subconditions[2], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)

# m51, p51 = pivdrops.process_piv_data(data_path, conditions[4], subconditions[0], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m52, p52 = pivdrops.process_piv_data(data_path, conditions[4], subconditions[1], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m53, p53 = pivdrops.process_piv_data(data_path, conditions[4], subconditions[2], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)

# m61, p61 = pivdrops.process_piv_data(data_path, conditions[5], subconditions[0], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m62, p62 = pivdrops.process_piv_data(data_path, conditions[5], subconditions[1], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m63, p63 = pivdrops.process_piv_data(data_path, conditions[5], subconditions[2], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)

# m71, p71 = pivdrops.process_piv_data(data_path, conditions[6], subconditions[0], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m72, p72 = pivdrops.process_piv_data(data_path, conditions[6], subconditions[1], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m73, p73 = pivdrops.process_piv_data(data_path, conditions[6], subconditions[2], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)

# m81, p81 = pivdrops.process_piv_data(data_path, conditions[7], subconditions[0], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m82, p82 = pivdrops.process_piv_data(data_path, conditions[7], subconditions[1], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m83, p83 = pivdrops.process_piv_data(data_path, conditions[7], subconditions[2], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)

# m91, p91 = pivdrops.process_piv_data(data_path, conditions[8], subconditions[0], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m92, p92 = pivdrops.process_piv_data(data_path, conditions[8], subconditions[1], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m93, p93 = pivdrops.process_piv_data(data_path, conditions[8], subconditions[2], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)

# m101, p101 = pivdrops.process_piv_data(data_path, conditions[9], subconditions[0], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m102, p102 = pivdrops.process_piv_data(data_path, conditions[9], subconditions[1], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m103, p103 = pivdrops.process_piv_data(data_path, conditions[9], subconditions[2], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)

# m111, p111 = pivdrops.process_piv_data(data_path, conditions[10], subconditions[0], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m112, p112 = pivdrops.process_piv_data(data_path, conditions[10], subconditions[1], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m113, p113 = pivdrops.process_piv_data(data_path, conditions[10], subconditions[2], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)

# m121, p121 = pivdrops.process_piv_data(data_path, conditions[11], subconditions[0], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m122, p122 = pivdrops.process_piv_data(data_path, conditions[11], subconditions[1], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
# m123, p123 = pivdrops.process_piv_data(data_path, conditions[11], subconditions[2], min_frame=min_frame, max_frame=max_frame, plot_autocorrelation=False)
